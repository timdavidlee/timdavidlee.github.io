# %% [markdown]
# <a id='home'></a>
# # Adventures in Data: Making a fake Balance Sheet and P&L data:
#
# ### Original Goal: I wanted to design cool applications for accounting/finance data.
#
# I originally wanted to setup some pipelines to dashboards in Tableau and D3. Wanted build some interesting pipelines, visualizations and some data automation. We had one client with several billion rows of data, and was perfect of gaining insights and optimizing for large scale processing. No other finance guy in excel is going to be able to extract decent insights from a dataset that big. But it didn't happen...
#
# ### Problem: Companies are shy - no company wants to publish their transactional data.
#
# Essentially, the company said no. In fact 2-3 different clients also said no. Understandably, companies are sensitive especially for profitability information. When I worked a few projects with pre-earnings release data, they locked us in a conference room and covered the glass entrance door with paper and tape to ensure the revenue numbers didn't pre-announcement. All the data was heavily password protected and segregated from the rest of the analytics team.
#
# ### Solution: Make a random data generator to generate detailed 10k balance sheets and P&L.
#
# So instead of hoping and waiting that there would be a nice company that would be nice to open it's innards for experimentation. I decided to see if i could make a design generic company data. This would be nice for a few reasons:
#
# Pros:
# - could generate data at will
# - no privacy issues
# - could share the piping / visualization code and the source data
#
# Cons:
# - have to design it
# - have to consider some "reasonableness" to the data
# - accounting data follows some specific rules
# - make it varied enough and interesting enough that 1000 dollars doesn't = 100 x 10, it should vary
# - stretch: design time-series incidents to the data
# - stretch: auto generate accounting transactions at a document level
#
# ### Current Project Status:
#
# - Oct 2016, prototyped the initial class, will generate annual data
#
# ### To do
#
# - Implement time-series by month
# - implement performance events
# - implement generation of document-level transactional data generation
# - implement "bad data" factor - arbitrarily remove different fields to simulate real data issues

# %% [markdown]
# ###  TLDR: Jump to the classes: RCU , FakeCompanyClass <a href=#class>link</a>

# %% [markdown]
# The completed class is long, and is located at the bottom of this page

# %% [markdown]
# # How I designed my class in Python

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## 1. A primer: Balance Sheets on company financials

# %% [markdown]
# Every company has one. Check on www.sec.gov to look up your favorite company. Look for either the 10Q or the 10K formal reports and lookup under "balance sheet". All companies have it. From a famous fruit company, take a look here:
# http://investor.apple.com/financials.cfm
#
#
# #### Definition
# From investopedia: http://www.investopedia.com/terms/b/balancesheet.asp
#
# "What is a 'Balance Sheet'
# A balance sheet is a financial statement that summarizes a company's assets, liabilities and shareholders' equity at a specific point in time. These three balance sheet segments give investors an idea as to what the company owns and owes, as well as the amount invested by shareholders.
#
# The balance sheet adheres to the following formula:
#
# Assets = Liabilities + Shareholders' Equity"

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## 2. Some Target Goals
#
# 1. Make it scalable, want to make 1000 rows or up to 100M rows of randomized data
# 2. Data must still follow the accounting rules, specific accounts must add up, certain line items should be negative
# 3. Will need to invent hierarchies for products (for doing hierarchical analysis)
# 4. Will need to general account hierarchies... e.g. Accounts Receiveable, and Allowance for doubtful accounts roll up under "receivables"
# 5. ideally the numbers should vary. While Assets = Liabilties + Equity, it shouldn't be 0.5 = 0.25 + 0.25 every single time

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## 3. Import Python Libraries
#
# As a note, pycountry is a great library for international country listings, codes, common numbers used. You may not know this, but this coding is used a lot in business for coding their data or legal entity reasons

# %%
# import libraries
import os
import pycountry
import random 
import string
import numpy as np
import pandas as pd
from random_words import RandomWords
from decimal import *

# %% [markdown]
# ####  Key python library: randomwords
#
# Instead of making everything boring with random numbers for IDs, will use words to make things more interesting. A sample is here below

# %%
for x in range (10):
    print RandomWords().random_word()
# Out:
# hums
# official
# picks
# dents
# prisons
# date
# peg
# lighters
# guys
# goal

# %% [markdown]
# # Designing Fake Data: easier said then done

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## 4. Setting up some general parameters common in company financials (how random):
# #### transactional detail, row count, legal entities, and accounts
#
# From my consulting career, it's never certain what is available to be plotted. Ideally, will want to also randomize available transactional detail. I've seeded a complete listing of some common fields that companies keep in their data. We will later randomly sample from the total "field options" list

# %%
maxfields = random.randint(2,10)
fieldOptions = ('COSTCTR','PROFITCTR','PRODCODE','SEGMENT','BUSAREA','PROGRAM','PROJECT','REFE','BGROUP','SKU','SYSTEM')
maxrows = random.randint(100,400)
maxentities = random.randint(4,30)

# will have a minimum of 2 accounts per balance sheet line item
maxaccounts = random.randint(40,120)

# %% [markdown]
# ### Setup standard balance sheet hierarchy
#
# #### These are the standard financial statement line items : FSLI and sub-level items
#
#     Balancesheet --> FSLI --> subFSLI --> Accounts --> Legal Entity --> Additional Product Detail
#
# From http://www.accountingtools.com/balance-sheet
#
#     Current Assets:
#
#     1-Cash and cash equivalents (+)
#     2-Trade and other receivables (+)
#     3-Investments (+)
#     4-Inventories (+)
#     5-Assets held for sale (+)
#
#     Non-Current Assets:
#     6-Property, plant, and equipment (+)
#     7-Intangible assets (+)
#     8-Goodwill (+)
#
#     Current Liabilities:
#
#     9-Trade and other payables (-)
#     10-Accrued expenses (-)
#     11-Current tax liabilities (-)
#     12-Current portion of loans payable (-)
#     13-Other financial liabilities (-)
#     14-Liabilities held for sale (-)
#
#     Non-Current Liabilities:
#     15-Loans payable (-)
#     16-Deferred tax liabilities (-)
#     17-Other non-current liabilities (-)
#
#     Equity:
#     18-Capital stock (-)
#     19-Additional paid-in capital (-)
#     20-Retained earnings (-)

# %% [markdown]
# #### Make a python dictionary of the above structure

# %%
#make a dictionary:
bs_def ={
    'assets':{
        'current':{
            'cash':1
            ,'trade_receivables':2
            ,'investments':3
            ,'inventories':4
            ,'assets_for_sale':5
        }
        ,'non-current':{
            'ppe':6
            ,'intangible':7
            ,'goodwill':8
        }
    }
    , 'liabilities':{
        'current':{
            'trade_payables':9
            ,'accrued_expenses':10
            ,'current_tax':11
            ,'current_loans':12
            ,'other_liab':13
            ,'liab_for_sale':14
        }
        ,'non-current':{
            'loans':15
            , 'def_tax':16
            , 'Other_non_liab':17
        
        }
        
    }
    , 'equity':{
        'equity':{
            'capital_stock':18
            , 'paid_capital':19
            ,'retained_earnings':20
           }
    }
}

# %%
bs_def
# Out:
# {'assets': {'current': {'assets_for_sale': 5,
#    'cash': 1,
#    'inventories': 4,
#    'investments': 3,
#    'trade_receivables': 2},
#   'non-current': {'goodwill': 8, 'intangible': 7, 'ppe': 6}},
#  'equity': {'equity': {'capital_stock': 18,
#    'paid_capital': 19,
#    'retained_earnings': 20}},
#  'liabilities': {'current': {'accrued_expenses': 10,
#    'current_loans': 12,
#    'current_tax': 11,
#    'liab_for_sale': 14,
#    'other_liab': 13,
#    'trade_payables': 9},
#   'non-current': {'Other_non_liab': 17, 'def_tax': 16, 'loans': 15}}}

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## 5. Seeding Initial Balances into the company structure
#
# Also, remember Assets = liabilties + equity. Will assign value to Assets, and Liabilities / Equity will be arbitrarily determined by picking a random distribution.

# %%
def seedCompany():
    # start with a couple of billion dollars as the inital company balance
    total_company_assets = random.randint(1,50)*1e9

    # back into liabilities with random % distribution
    total_company_liabilities = -random.random()*total_company_assets
    total_company_equity = -(total_company_assets + total_company_liabilities)

    # print the current total balances
    print 'Assets \t\t', "{:,}".format(total_company_assets)
    print 'Liabilities \t', "{:,}".format(total_company_liabilities)
    print 'Equity \t\t', "{:,}".format(total_company_equity)

    company = {
        'assets' :total_company_assets
        , 'liabilities' : total_company_liabilities
        , 'equity': total_company_equity
    }
    return company

company = seedCompany()
# Out:
# Assets 		5,000,000,000.0
# Liabilities 	-2,520,892,265.82
# Equity 		-2,479,107,734.18

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## 6. Setting up common randomized split functions

# %% [markdown]
# ### Create a random splitting function - takes in total balances and splits randomly n times

# %% [markdown]
# #### Defintion: Pct Split functions
#
# First returns a all-positive percentage that adds up to 1
# Second returns a positive or negative percetange list that still adds up to 1, but may have swing values

# %%
def splitPosPct(n,swing=100):
    rand_nums = np.array([random.randint(1,swing) for i in range(n)])
    return rand_nums*1.0 / sum(rand_nums)

def splitSwingPct(n,swing=100):
    rand_nums = np.array([random.randint(-int(swing/2),int(swing/2)) for i in range(n)])
    return rand_nums*1.0 / sum(rand_nums)

# %% [markdown]
# #### Sample

# %%
print splitPosPct(6)
print splitSwingPct(6)
# Out:
# [ 0.13986014  0.26223776  0.04195804  0.21328671  0.25174825  0.09090909]
# [-7.    8.75 -7.25  0.75  6.5  -0.75]

# %% [markdown]
# #### Definition: Sum split
# For a input sum, returns n random integers that add up to the original sum

# %%
def intSplit(count,n, minm=0,swing=100):
    base = [minm for i in range(n)]
    subcount = count - sum(base)
    first = [int(x*int(subcount)) for x in splitPosPct(n,swing)][:-1]
    first.append(subcount-sum(first))
    
    return list(np.array(first)+np.array(base))

# %% [markdown]
# #### Sample

# %%
print intSplit(17,5,2), sum(intSplit(17,5,1))
# Out:
# [3, 3, 3, 3, 5] 17

# %% [markdown]
# #### Definition: Sublist split by n, with minimum counts
#
# Takes in a list and returns n lists with random subsets. Can set minimum for list

# %%
def listSplit(inputlist,n,minm=2,swing=100):
    inlist = inputlist[:]
    inlist.sort()
    divs = intSplit(len(inlist),n,minm,swing=100)
    outlist = []
    print divs
    for x in divs:
        divlist = []
        for i in range(x):
            divlist.append(inlist.pop(0))
        outlist.append(divlist)
    return outlist

# %% [markdown]
# #### Sample

# %%
print listSplit(['a','b','c','d','e','f','g','h','j','k','l','m','n','o','p','q'],4)
# Out:
# [2, 4, 4, 6]
# [['a', 'b'], ['c', 'd', 'e', 'f'], ['g', 'h', 'j', 'k'], ['l', 'm', 'n', 'o', 'p', 'q']]

# %% [markdown]
# #### Definition: Balance split (same direction )
#
# Takes in a total and uses pct split to make arbitrary balances

# %%
def splitBalance(total, n, swing=100):
    return splitPosPct(n,swing)*total

splitBalance(10, 5,swing=100)
# Out:
# array([ 1.16883117,  2.53246753,  0.45454545,  4.02597403,  1.81818182])

# %% [markdown]
# #### Postive / negative split (for lower level) - this is to mimic how accounting transactions open and close

# %%
def splitSwingBalance(total, n, swing=100):
    return splitSwingPct(n,swing) * total
# sample of 10 dollars
splitSwingBalance(10, 5,swing=100)
# Out:
# array([  5.8974359 ,   8.46153846,   9.74358974,  -3.84615385, -10.25641026])

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## 7. Design a Class for Financial Units
#
# Each balance will have the following:
#
#     RCU Class
#         Name:
#         Total: USD Balance
#         Items List: of other RCUs
#
# Its fairly straightforward and is designed for nesting. So if we had "bank account" for $100, it might be made up of "saving 50", "checking 20", and "stock 30" RCU units. Many of the functions are designed for recursive calls for splitting end nodes, or for printing dynamic depth trees
#
#
# ** Sample of Nesting **
#
#     RCU Class
#         Name: RCU_BASE
#         Total: USD Balance
#         Items List: RCU_A, RCU_B, ...
#
#             RCU Class
#                 Name: RCU_A
#                 Total: USD Balance
#                 Items List: RCU_AA, RCU_BB,..
#
#                 ..

# %%
class RCU(object):
    def __init__(self, name, total):
        self.name = name
        self.total = total
        self.delimiter = '|'
        self.items = {}
        
    def __str__(self):
        return 'name: %s , total: %s' % (self.name, "{:,}".format(self.total))
    
    def getItems(self):
        return self.items.values()
    
    #using recursive print
    def printItems(self,n=0):
        g = self.getItems()
        print n*'\t',self
        n+=1
        for x in g:
            x.printItems(n)
    
    def splitItems(self, labels,swing=100):
        n = len(labels)
        self.items = { j: RCU(j,k) for j,k in zip(labels, splitBalance(self.total,n,swing=100))}
        
    def explictItems(self, in_dict):
        if sum(in_dict.values()) == self.total:
            self.items = { j: RCU(j,k) for j,k in in_dict.items()}
        else:
            print 'total balance doesnt match submitted breakout of items'
    def splitEnds(self,labels):
        if len(self.getItems()) == 0:
            self.splitItems(random.sample(labels,int(len(labels)*.75)))
        else:
            for x in self.getItems():
                x.splitEnds(labels)
                
    def flatten(self):
        if len(self.getItems()) == 0:
            return [self.name+self.delimiter+str(self.total)]
        else:
            return_list = []
            for x in self.getItems():
                for y in x.flatten():
                    return_list.append(self.name +self.delimiter+ y)
            return return_list

# %% [markdown]
# ### Testing the RCU class

# %%
#create a generic RCU
newrcu = RCU('fakecompany', 100)
print newrcu

# split the initial balance of 100 by 3 different labels listed below
newrcu.splitItems(['apple','banana','pirate'])

# test the nested print function
newrcu.printItems()

# test the recursive print function
newrcu.explictItems({'apple':20 ,'banana':30,'pirate':50})

# test the recursive split function 
newrcu.splitEnds(['half','other_half','other_other_half'])
newrcu.printItems()
# Out:
# name: fakecompany , total: 100
#  name: fakecompany , total: 100
# 	name: pirate , total: 62.0689655172
# 	name: apple , total: 4.31034482759
# 	name: banana , total: 33.6206896552
#  name: fakecompany , total: 100
# 	name: pirate , total: 50
# 		name: other_other_half , total: 21.1409395973
# 		name: half , total: 28.8590604027
# 	name: banana , total: 30
# 		name: other_half , total: 6.71052631579
# 		name: half , total: 23.2894736842
# 	name: apple , total: 20
# 		name: half , total: 14.8275862069
# 		name: other_other_half , total: 5.1724137931

# %%
# test the recursive flatten function.
# should turn the nested dictionary into 
# pipe delimited lines with repeated values
print newrcu.flatten()
# Out:
# ['fakecompany|pirate|other_other_half|21.1409395973', 'fakecompany|pirate|half|28.8590604027', 'fakecompany|banana|other_half|6.71052631579', 'fakecompany|banana|half|23.2894736842', 'fakecompany|apple|half|14.8275862069', 'fakecompany|apple|other_other_half|5.1724137931']

# %% [markdown]
# ## Pilot: Use my data structure to setup my first company!

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 8. Initialize highest level items ( Asset / Liab)
#
#     Fakecompany --> FSLI Split
#     Fakecompany = 0 dollars (accounting rule), balance sheets must "balance" which means the total = 0

# %%
mycompany = seedCompany()

fakecompany = RCU('fakecompany', 0)
fakecompany.explictItems(mycompany)
# Out:
# Assets 		49,000,000,000.0
# Liabilities 	-276,133,861.848
# Equity 		-48,723,866,138.2

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 9. First Split: initialize below level items (current / non current)
#
#     Fakecompany --> FSLI --> subFSLI split

# %%
for x in fakecompany.getItems():
    x.splitItems(bs_def[x.name].keys())
    for y in x.getItems():
        y.splitItems(bs_def[x.name][y.name].keys(),swing=10000)

# %%
fakecompany.printItems()
# Out:
#  name: fakecompany , total: 0
# 	name: liabilities , total: -276,133,861.848
# 		name: current , total: -201,790,129.812
# 			name: trade_payables , total: -26,780,788.8331
# 			name: accrued_expenses , total: -53,561,577.6662
# 			name: liab_for_sale , total: -28,026,406.9184
# 			name: other_liab , total: -19,929,889.3642
# 			name: current_tax , total: -39,236,969.6857
# 			name: current_loans , total: -34,254,497.3447
# 		name: non-current , total: -74,343,732.0361
# 			name: def_tax , total: -21,706,199.1346
# 			name: Other_non_liab , total: -51,552,222.9447
# 			name: loans , total: -1,085,309.95673
# 	name: assets , total: 49,000,000,000.0
# 		name: current , total: 24,752,577,319.6
# 			name: trade_receivables , total: 11,078,076,562.6
# 			name: inventories , total: 5,192,848,388.72
# 			name: assets_for_sale , total: 865,474,731.454
# 			name: investments , total: 6,750,702,905.34
# 			name: cash , total: 865,474,731.454
# 		name: non-current , total: 24,247,422,680.4
# 			name: intangible , total: 9,041,411,846.93
# 			name: ppe , total: 7,089,288,834.53
# 			name: goodwill , total: 8,116,721,998.95
# 	name: equity , total: -48,723,866,138.2
# 		name: equity , total: -48,723,866,138.2
# 			name: capital_stock , total: -25,391,310,522.7
# 			name: paid_capital , total: -6,862,516,357.49
# 			name: retained_earnings , total: -16,470,039,258.0

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 10. Randomly generate the number of accounts - will choose 4 digit accounts to keep it simple

# %%
asset_accounts = [str(x).zfill(4) for x in random.sample(xrange(1000,1999), maxaccounts)]
liab_accounts = [str(x).zfill(4) for x in random.sample(xrange(2000,2899), maxaccounts)]
equity_accounts = [str(x).zfill(4) for x in random.sample(xrange(2900,2999), 10)]

asset_accounts.sort()
liab_accounts.sort()
equity_accounts.sort()
print asset_accounts
print liab_accounts
print equity_accounts
# Out:
# ['1000', '1016', '1021', '1023', '1039', '1042', '1050', '1060', '1090', '1096', '1127', '1172', '1185', '1203', '1210', '1232', '1238', '1241', '1287', '1309', '1329', '1347', '1363', '1364', '1397', '1418', '1425', '1431', '1450', '1463', '1468', '1487', '1497', '1504', '1511', '1515', '1517', '1520', '1522', '1528', '1551', '1554', '1574', '1577', '1585', '1606', '1630', '1687', '1689', '1752', '1754', '1758', '1777', '1783', '1798', '1810', '1814', '1873', '1903', '1904', '1905', '1924', '1934', '1968', '1983', '1994']
# ['2011', '2017', '2025', '2031', '2035', '2038', '2040', '2049', '2071', '2080', '2085', '2090', '2093', '2097', '2098', '2123', '2124', '2135', '2148', '2175', '2193', '2224', '2244', '2256', '2266', '2270', '2283', '2287', '2299', '2315', '2332', '2343', '2350', '2358', '2383', '2394', '2412', '2414', '2439', '2452', '2459', '2464', '2468', '2471', '2526', '2553', '2597', '2599', '2643', '2664', '2699', '2707', '2711', '2744', '2760', '2763', '2770', '2783', '2786', '2794', '2828', '2832', '2849', '2878', '2880', '2887']
# ['2904', '2911', '2941', '2954', '2970', '2972', '2980', '2982', '2986', '2989']

# %%
print listSplit(asset_accounts,5,2)
# Out:
# [2, 21, 5, 23, 15]
# [['1000', '1016'], ['1021', '1023', '1039', '1042', '1050', '1060', '1090', '1096', '1127', '1172', '1185', '1203', '1210', '1232', '1238', '1241', '1287', '1309', '1329', '1347', '1363'], ['1364', '1397', '1418', '1425', '1431'], ['1450', '1463', '1468', '1487', '1497', '1504', '1511', '1515', '1517', '1520', '1522', '1528', '1551', '1554', '1574', '1577', '1585', '1606', '1630', '1687', '1689', '1752', '1754'], ['1758', '1777', '1783', '1798', '1810', '1814', '1873', '1903', '1904', '1905', '1924', '1934', '1968', '1983', '1994']]

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 11. will do random account assignment to further split the values

# %% [markdown]
#     Fakecompany --> FSLI --> subFSLI --> account split

# %%
for x in fakecompany.items['assets'].getItems():
    print len(x.getItems())
    acct_ct = listSplit(asset_accounts,len(x.getItems()),2)
    print acct_ct
    for y,accts in zip(x.getItems(),acct_ct):
        y.splitItems(accts)

        
for x in fakecompany.items['liabilities'].getItems():
    print len(x.getItems())
    acct_ct = listSplit(liab_accounts,len(x.getItems()),2)
    print acct_ct
    for y,accts in zip(x.getItems(),acct_ct):
        y.splitItems(accts)
        
for x in fakecompany.items['equity'].getItems():
    print len(x.getItems())
    acct_ct = listSplit(equity_accounts,len(x.getItems()),2)
    print acct_ct
    for y,accts in zip(x.getItems(),acct_ct):
        y.splitItems(accts)
        
fakecompany.printItems()
# Out:
# 5
# [28, 2, 25, 2, 9]
# [['1000', '1016', '1021', '1023', '1039', '1042', '1050', '1060', '1090', '1096', '1127', '1172', '1185', '1203', '1210', '1232', '1238', '1241', '1287', '1309', '1329', '1347', '1363', '1364', '1397', '1418', '1425', '1431'], ['1450', '1463'], ['1468', '1487', '1497', '1504', '1511', '1515', '1517', '1520', '1522', '1528', '1551', '1554', '1574', '1577', '1585', '1606', '1630', '1687', '1689', '1752', '1754', '1758', '1777', '1783', '1798'], ['1810', '1814'], ['1873', '1903', '1904', '1905', '1924', '1934', '1968', '1983', '1994']]
# 3
# [28, 2, 36]
# [['1000', '1016', '1021', '1023', '1039', '1042', '1050', '1060', '1090', '1096', '1127', '1172', '1185', '1203', '1210', '1232', '1238', '1241', '1287', '1309', '1329', '1347', '1363', '1364', '1397', '1418', '1425', '1431'], ['1450', '1463'], ['1468', '1487', '1497', '1504', '1511', '1515', '1517', '1520', '1522', '1528', '1551', '1554', '1574', '1577', '1585', '1606', '1630', '1687', '1689', '1752', '1754', '1758', '1777', '1783', '1798', '1810', '1814', '1873', '1903', '1904', '1905', '1924', '1934', '1968', '1983', '1994']]
# 6
# [5, 8, 8, 14, 12, 19]
# [['2011', '2017', '2025', '2031', '2035'], ['2038', '2040', '2049', '2071', '2080', '2085', '2090', '2093'], ['2097', '2098', '2123', '2124', '2135', '2148', '2175', '2193'], ['2224', '2244', '2256', '2266', '2270', '2283', '2287', '2299', '2315', '2332', '2343', '2350', '2358', '2383'], ['2394', '2412', '2414', '2439', '2452', '2459', '2464', '2468', '2471', '2526', '2553', '2597'], ['2599', '2643', '2664', '2699', '2707', '2711', '2744', '2760', '2763', '2770', '2783', '2786', '2794', '2828', '2832', '2849', '2878', '2880', '2887']]
# 3
# [32, 9, 25]
# [['2011', '2017', '2025', '2031', '2035', '2038', '2040', '2049', '2071', '2080', '2085', '2090', '2093', '2097', '2098', '2123', '2124', '2135', '2148', '2175', '2193', '2224', '2244', '2256', '2266', '2270', '2283', '2287', '2299', '2315', '2332', '2343'], ['2350', '2358', '2383', '2394', '2412', '2414', '2439', '2452', '2459'], ['2464', '2468', '2471', '2526', '2553', '2597', '2599', '2643', '2664', '2699', '2707', '2711', '2744', '2760', '2763', '2770', '2783', '2786', '2794', '2828', '2832', '2849', '2878', '2880', '2887']]
# 3
# [3, 2, 5]
# [['2904', '2911', '2941'], ['2954', '2970'], ['2972', '2980', '2982', '2986', '2989']]
#  name: fakecompany , total: 0
# 	name: liabilities , total: -276,133,861.848
# 		name: current , total: -201,790,129.812
# 			name: trade_payables , total: -26,780,788.8331
# 				name: 2025 , total: -3,997,132.66166
# 				name: 2017 , total: -8,260,740.83409
# 				name: 2011 , total: -13,190,537.7835
# 				name: 2035 , total: -932,664.28772
# 				name: 2031 , total: -399,713.266166
# 			name: accrued_expenses , total: -53,561,577.6662
# 				name: 2040 , total: -399,713.266166
# 				name: 2080 , total: -3,330,943.88472
# 				name: 2049 , total: -12,924,062.2727
# 				name: 2090 , total: -12,924,062.2727
# 				name: 2093 , total: -5,995,698.99249
# 				name: 2071 , total: -9,859,593.89876
# 				name: 2085 , total: -133,237.755389
# 				name: 2038 , total: -7,994,265.32332
# 			name: liab_for_sale , total: -28,026,406.9184
# 				name: 2123 , total: -3,380,069.17609
# 				name: 2135 , total: -3,168,814.85258
# 				name: 2124 , total: -3,098,396.74474
# 				name: 2097 , total: -704,181.078351
# 				name: 2193 , total: -6,126,375.38165
# 				name: 2175 , total: -5,703,866.73464
# 				name: 2098 , total: -2,253,379.45072
# 				name: 2148 , total: -3,591,323.49959
# 			name: other_liab , total: -19,929,889.3642
# 				name: 2299 , total: -2,079,199.65377
# 				name: 2315 , total: -2,003,131.37375
# 				name: 2270 , total: -1,876,350.90706
# 				name: 2343 , total: -2,129,911.84045
# 				name: 2383 , total: -2,282,048.40048
# 				name: 2224 , total: -608,546.240128
# 				name: 2283 , total: -1,876,350.90706
# 				name: 2332 , total: -2,459,541.05385
# 				name: 2287 , total: -1,546,721.69366
# 				name: 2358 , total: -228,204.840048
# 				name: 2244 , total: -481,765.773434
# 				name: 2256 , total: -152,136.560032
# 				name: 2350 , total: -1,648,146.06701
# 				name: 2266 , total: -557,834.05345
# 			name: current_tax , total: -39,236,969.6857
# 				name: 2464 , total: -5,031,683.93638
# 				name: 2439 , total: -3,201,980.68679
# 				name: 2526 , total: -4,777,558.48505
# 				name: 2459 , total: -1,524,752.70799
# 				name: 2471 , total: -4,269,307.58238
# 				name: 2468 , total: -2,744,554.87439
# 				name: 2553 , total: -3,354,455.95759
# 				name: 2452 , total: -3,557,756.31865
# 				name: 2394 , total: -813,201.444264
# 				name: 2412 , total: -3,964,357.04079
# 				name: 2414 , total: -3,303,630.86732
# 				name: 2597 , total: -2,693,729.78412
# 			name: current_loans , total: -34,254,497.3447
# 				name: 2786 , total: -2,934,388.75855
# 				name: 2880 , total: -1,796,564.54605
# 				name: 2711 , total: -1,616,908.09144
# 				name: 2887 , total: -1,257,595.18223
# 				name: 2783 , total: -479,083.878947
# 				name: 2849 , total: -898,282.273025
# 				name: 2763 , total: -1,736,679.06118
# 				name: 2707 , total: -359,312.90921
# 				name: 2643 , total: -2,664,904.07664
# 				name: 2599 , total: -1,946,278.25822
# 				name: 2878 , total: -2,215,762.94013
# 				name: 2770 , total: -838,396.788157
# 				name: 2664 , total: -2,874,503.27368
# 				name: 2760 , total: -1,736,679.06118
# 				name: 2828 , total: -2,125,934.71283
# 				name: 2744 , total: -2,934,388.75855
# 				name: 2699 , total: -1,437,251.63684
# 				name: 2832 , total: -2,545,133.1069
# 				name: 2794 , total: -1,856,450.03092
# 		name: non-current , total: -74,343,732.0361
# 			name: def_tax , total: -21,706,199.1346
# 				name: 2299 , total: -255,367.048643
# 				name: 2097 , total: -297,928.223417
# 				name: 2193 , total: -226,992.932127
# 				name: 2090 , total: -1,021,468.19457
# 				name: 2093 , total: -1,120,777.60238
# 				name: 2085 , total: -368,863.514706
# 				name: 2098 , total: -1,092,403.48586
# 				name: 2135 , total: -1,120,777.60238
# 				name: 2343 , total: -1,319,396.41799
# 				name: 2224 , total: -922,158.786765
# 				name: 2035 , total: -1,234,274.06844
# 				name: 2031 , total: -766,101.145928
# 				name: 2175 , total: -453,985.864254
# 				name: 2244 , total: -567,482.330317
# 				name: 2017 , total: -297,928.223417
# 				name: 2011 , total: -922,158.786765
# 				name: 2038 , total: -1,262,648.18496
# 				name: 2283 , total: -113,496.466063
# 				name: 2332 , total: -453,985.864254
# 				name: 2287 , total: -751,914.08767
# 				name: 2071 , total: -156,057.640837
# 				name: 2270 , total: -978,907.019797
# 				name: 2123 , total: -354,676.456448
# 				name: 2124 , total: -425,611.747738
# 				name: 2040 , total: -993,094.078055
# 				name: 2266 , total: -170,244.699095
# 				name: 2080 , total: -822,849.37896
# 				name: 2315 , total: -822,849.37896
# 				name: 2049 , total: -127,683.524321
# 				name: 2025 , total: -680,978.796381
# 				name: 2256 , total: -255,367.048643
# 				name: 2148 , total: -1,347,770.5345
# 			name: Other_non_liab , total: -51,552,222.9447
# 				name: 2439 , total: -8,780,873.13894
# 				name: 2459 , total: -3,210,211.6852
# 				name: 2383 , total: -8,308,783.18523
# 				name: 2358 , total: -3,399,047.66669
# 				name: 2452 , total: -4,909,735.51855
# 				name: 2394 , total: -9,064,127.11116
# 				name: 2412 , total: -6,609,259.35189
# 				name: 2414 , total: -5,192,989.49077
# 				name: 2350 , total: -2,077,195.79631
# 			name: loans , total: -1,085,309.95673
# 				name: 2711 , total: -83,704.8871099
# 				name: 2471 , total: -32,340.5245652
# 				name: 2849 , total: -26,633.3731713
# 				name: 2770 , total: -19,023.8379795
# 				name: 2599 , total: -69,437.0086252
# 				name: 2597 , total: -10,463.1108887
# 				name: 2828 , total: -69,437.0086252
# 				name: 2880 , total: -64,681.0491304
# 				name: 2526 , total: -65,632.2410293
# 				name: 2887 , total: -25,682.1812724
# 				name: 2783 , total: -30,438.1407672
# 				name: 2664 , total: -92,265.6142007
# 				name: 2744 , total: -91,314.4223017
# 				name: 2464 , total: -55,169.1301406
# 				name: 2760 , total: -13,316.6865857
# 				name: 2763 , total: -2,853.57569693
# 				name: 2707 , total: -64,681.0491304
# 				name: 2643 , total: -25,682.1812724
# 				name: 2468 , total: -88,460.8466048
# 				name: 2786 , total: -27,584.5650703
# 				name: 2832 , total: -2,853.57569693
# 				name: 2553 , total: -27,584.5650703
# 				name: 2878 , total: -41,852.4435549
# 				name: 2699 , total: -40,901.251656
# 				name: 2794 , total: -13,316.6865857
# 	name: assets , total: 49,000,000,000.0
# 		name: current , total: 24,752,577,319.6
# 			name: trade_receivables , total: 11,078,076,562.6
# 				name: 1329 , total: 713,031,615.49
# 				name: 1210 , total: 591,294,510.406
# 				name: 1203 , total: 243,474,210.167
# 				name: 1347 , total: 17,391,015.012
# 				name: 1050 , total: 799,986,690.55
# 				name: 1418 , total: 60,868,552.5418
# 				name: 1425 , total: 834,768,720.574
# 				name: 1039 , total: 391,297,837.769
# 				name: 1397 , total: 869,550,750.598
# 				name: 1016 , total: 17,391,015.012
# 				name: 1096 , total: 182,605,657.625
# 				name: 1090 , total: 573,903,495.394
# 				name: 1172 , total: 269,560,732.685
# 				name: 1232 , total: 234,778,702.661
# 				name: 1238 , total: 539,121,465.37
# 				name: 1309 , total: 8,695,507.50598
# 				name: 1127 , total: 226,083,195.155
# 				name: 1042 , total: 95,650,582.5657
# 				name: 1287 , total: 17,391,015.012
# 				name: 1021 , total: 573,903,495.394
# 				name: 1023 , total: 730,422,630.502
# 				name: 1431 , total: 869,550,750.598
# 				name: 1060 , total: 313,038,270.215
# 				name: 1185 , total: 486,948,420.335
# 				name: 1241 , total: 260,865,225.179
# 				name: 1364 , total: 556,512,480.382
# 				name: 1363 , total: 252,169,717.673
# 				name: 1000 , total: 347,820,300.239
# 			name: inventories , total: 5,192,848,388.72
# 				name: 1450 , total: 4,804,598,041.9
# 				name: 1463 , total: 388,250,346.821
# 			name: assets_for_sale , total: 865,474,731.454
# 				name: 1783 , total: 61,278,640.4928
# 				name: 1487 , total: 48,885,207.5841
# 				name: 1630 , total: 12,393,432.9087
# 				name: 1777 , total: 55,770,448.0889
# 				name: 1585 , total: 34,426,202.524
# 				name: 1520 , total: 41,311,443.0288
# 				name: 1468 , total: 4,131,144.30288
# 				name: 1522 , total: 57,836,020.2404
# 				name: 1758 , total: 11,016,384.8077
# 				name: 1754 , total: 47,508,159.4832
# 				name: 1528 , total: 7,573,764.55529
# 				name: 1752 , total: 14,459,005.0601
# 				name: 1798 , total: 42,688,491.1298
# 				name: 1504 , total: 4,131,144.30288
# 				name: 1515 , total: 60,590,116.4423
# 				name: 1497 , total: 48,885,207.5841
# 				name: 1551 , total: 21,344,245.5649
# 				name: 1554 , total: 46,819,635.4327
# 				name: 1577 , total: 44,065,539.2308
# 				name: 1606 , total: 15,836,053.1611
# 				name: 1687 , total: 59,213,068.3413
# 				name: 1689 , total: 37,868,822.7764
# 				name: 1517 , total: 59,213,068.3413
# 				name: 1511 , total: 7,573,764.55529
# 				name: 1574 , total: 20,655,721.5144
# 			name: investments , total: 6,750,702,905.34
# 				name: 1814 , total: 3,179,363,303.81
# 				name: 1810 , total: 3,571,339,601.54
# 			name: cash , total: 865,474,731.454
# 				name: 1968 , total: 196,117,426.832
# 				name: 1983 , total: 174,800,315.22
# 				name: 1924 , total: 55,424,490.1916
# 				name: 1873 , total: 108,717,269.222
# 				name: 1934 , total: 51,161,067.8692
# 				name: 1904 , total: 89,531,868.7711
# 				name: 1905 , total: 4,263,422.32243
# 				name: 1903 , total: 14,921,978.1285
# 				name: 1994 , total: 170,536,892.897
# 		name: non-current , total: 24,247,422,680.4
# 			name: intangible , total: 9,041,411,846.93
# 				name: 1329 , total: 309,063,325.011
# 				name: 1210 , total: 492,405,975.441
# 				name: 1203 , total: 272,394,794.925
# 				name: 1347 , total: 450,499,083.914
# 				name: 1050 , total: 141,435,758.903
# 				name: 1418 , total: 350,970,216.538
# 				name: 1425 , total: 471,452,529.678
# 				name: 1039 , total: 293,348,240.688
# 				name: 1397 , total: 424,307,276.71
# 				name: 1016 , total: 345,731,855.097
# 				name: 1096 , total: 466,214,168.237
# 				name: 1090 , total: 314,301,686.452
# 				name: 1172 , total: 288,109,879.248
# 				name: 1232 , total: 293,348,240.688
# 				name: 1238 , total: 110,005,590.258
# 				name: 1309 , total: 324,778,409.334
# 				name: 1127 , total: 387,638,746.624
# 				name: 1042 , total: 288,109,879.248
# 				name: 1287 , total: 429,545,638.151
# 				name: 1021 , total: 167,627,566.108
# 				name: 1023 , total: 272,394,794.925
# 				name: 1431 , total: 492,405,975.441
# 				name: 1060 , total: 398,115,469.506
# 				name: 1185 , total: 303,824,963.57
# 				name: 1241 , total: 319,540,047.893
# 				name: 1364 , total: 89,052,144.4947
# 				name: 1363 , total: 413,830,553.828
# 				name: 1000 , total: 130,959,036.022
# 			name: ppe , total: 7,089,288,834.53
# 				name: 1450 , total: 1,820,222,808.87
# 				name: 1463 , total: 5,269,066,025.66
# 			name: goodwill , total: 8,116,721,998.95
# 				name: 1783 , total: 181,808,108.488
# 				name: 1487 , total: 157,567,027.356
# 				name: 1873 , total: 258,571,532.072
# 				name: 1904 , total: 56,562,522.6408
# 				name: 1905 , total: 177,767,928.3
# 				name: 1903 , total: 181,808,108.488
# 				name: 1630 , total: 327,254,595.279
# 				name: 1777 , total: 185,848,288.677
# 				name: 1810 , total: 60,602,702.8294
# 				name: 1983 , total: 234,330,450.94
# 				name: 1934 , total: 64,642,883.018
# 				name: 1585 , total: 399,977,838.674
# 				name: 1520 , total: 222,209,910.374
# 				name: 1468 , total: 404,018,018.863
# 				name: 1522 , total: 347,455,496.222
# 				name: 1758 , total: 214,129,549.997
# 				name: 1754 , total: 141,406,306.602
# 				name: 1528 , total: 169,687,567.922
# 				name: 1752 , total: 258,571,532.072
# 				name: 1814 , total: 222,209,910.374
# 				name: 1798 , total: 80,803,603.7725
# 				name: 1504 , total: 331,294,775.467
# 				name: 1515 , total: 121,205,405.659
# 				name: 1497 , total: 395,937,658.485
# 				name: 1968 , total: 391,897,478.297
# 				name: 1994 , total: 294,933,153.77
# 				name: 1551 , total: 161,607,207.545
# 				name: 1554 , total: 307,053,694.336
# 				name: 1577 , total: 32,321,441.509
# 				name: 1606 , total: 266,651,892.449
# 				name: 1687 , total: 145,446,486.791
# 				name: 1689 , total: 218,169,730.186
# 				name: 1924 , total: 282,812,613.204
# 				name: 1517 , total: 391,897,478.297
# 				name: 1511 , total: 60,602,702.8294
# 				name: 1574 , total: 367,656,397.165
# 	name: equity , total: -48,723,866,138.2
# 		name: equity , total: -48,723,866,138.2
# 			name: capital_stock , total: -25,391,310,522.7
# 				name: 2911 , total: -7,727,790,159.08
# 				name: 2941 , total: -9,032,482,004.12
# 				name: 2904 , total: -8,631,038,359.49
# 			name: paid_capital , total: -6,862,516,357.49
# 				name: 2954 , total: -3,194,619,683.66
# 				name: 2970 , total: -3,667,896,673.83
# 			name: retained_earnings , total: -16,470,039,258.0
# 				name: 2972 , total: -2,589,176,477.23
# 				name: 2982 , total: -4,890,666,679.22
# 				name: 2989 , total: -1,726,117,651.49
# 				name: 2980 , total: -2,948,784,321.3
# 				name: 2986 , total: -4,315,294,128.72

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 12. Adding Legal Entity, anywhere from 1-6 subentities per country

# %% [markdown]
#     Fakecompany --> FSLI --> subFSLI --> account --> legal Entity

# %%
alpha3 = [x.alpha3 for x in list(pycountry.countries)]
alpha3_entity = []

#typical transfer pricing legal entities
le_functions = ['factory', 'distributor', 'sales','rd_center','tax_entity','hq']
for y in alpha3:
    alpha3_entity.extend([str(y)+str(z)+'-'+random.sample(le_functions,1)[0] for z in range(1,random.randint(1,5))])

#total dictionary of possible entities    
print len(alpha3_entity)
# Out:
# 501

# %%
# will choose only 30-80 legal entities
random_le = random.sample(alpha3_entity,random.randint(30,80))
random_le.sort()
fakecompany.splitEnds(random_le)

# %%
fakecompany.printItems()
# Out:
#  name: fakecompany , total: 0
# 	name: liabilities , total: -276,133,861.848
# 		name: current , total: -201,790,129.812
# 			name: trade_payables , total: -26,780,788.8331
# 				name: 2025 , total: -3,997,132.66166
# 					name: DMA2-sales , total: -168,638.444791
# 					name: GRD1-sales , total: -98,372.4261282
# 					name: ARM1-factory , total: -94,357.2250618
# 					name: AGO3-sales , total: -180,684.047991
# 					name: MYS3-hq , total: -194,737.251723
# 					name: NPL2-tax_entity , total: -114,433.230394
# 					name: MAC2-factory , total: -60,228.0159969
# 					name: TLS3-distributor , total: -18,068.4047991
# 					name: GUM2-factory , total: -108,410.428794
# 					name: ATA1-tax_entity , total: -18,068.4047991
# 					name: HND2-tax_entity , total: -66,250.8175966
# 					name: COD1-hq , total: -170,646.045324
# 					name: FLK1-distributor , total: -74,281.2197295
# 					name: SXM3-factory , total: -62,235.6165301
# 					name: HKG2-factory , total: -98,372.4261282
# 					name: BFA3-distributor , total: -62,235.6165301
# 					name: ISL1-factory , total: -58,220.4154636
# 					name: CUW1-distributor , total: -112,425.629861
# 					name: DJI2-factory , total: -22,083.6058655
# 					name: CPV3-tax_entity , total: -24,091.2063987
# 					name: IND2-rd_center , total: -44,167.211731
# 					name: POL1-tax_entity , total: -106,402.828261
# 					name: SWE2-factory , total: -198,752.45279
# 					name: LUX2-distributor , total: -42,159.6111978
# 					name: DJI3-sales , total: -122,463.632527
# 					name: ARG1-sales , total: -126,478.833593
# 					name: TJK2-rd_center , total: -180,684.047991
# 					name: BES3-tax_entity , total: -166,630.844258
# 					name: MWI2-sales , total: -80,304.0213292
# 					name: HMD1-rd_center , total: -126,478.833593
# 					name: AGO2-rd_center , total: -134,509.235726
# 					name: NCL2-factory , total: -118,448.431461
# 					name: VAT3-sales , total: -138,524.436793
# 					name: LIE2-tax_entity , total: -108,410.428794
# 					name: KHM2-rd_center , total: -146,554.838926
# 					name: LUX4-sales , total: -168,638.444791
# 					name: LKA1-distributor , total: -180,684.047991
# 				name: 2017 , total: -8,260,740.83409
# 					name: AGO2-rd_center , total: -116,966.241899
# 					name: GRD1-sales , total: -336,277.945459
# 					name: NER1-rd_center , total: -180,322.95626
# 					name: ARM1-factory , total: -219,311.70356
# 					name: AGO3-sales , total: -238,806.07721
# 					name: MYS3-hq , total: -238,806.07721
# 					name: NPL2-tax_entity , total: -472,738.561007
# 					name: ATF2-factory , total: -263,174.044272
# 					name: TLS3-distributor , total: -243,679.670622
# 					name: DZA1-tax_entity , total: -263,174.044272
# 					name: ATA1-tax_entity , total: -219,311.70356
# 					name: HND2-tax_entity , total: -448,370.593945
# 					name: COD1-hq , total: -341,151.538871
# 					name: SXM3-factory , total: -121,839.835311
# 					name: HKG2-factory , total: -204,690.923323
# 					name: ISL1-factory , total: -151,081.395786
# 					name: CUW1-distributor , total: -321,657.165221
# 					name: DJI2-factory , total: -307,036.384984
# 					name: JAM2-sales , total: -160,828.582611
# 					name: CPV3-tax_entity , total: -190,070.143085
# 					name: MAC1-distributor , total: -268,047.637684
# 					name: COG1-tax_entity , total: -14,620.7802373
# 					name: IND2-rd_center , total: -458,117.78077
# 					name: IND3-hq , total: -448,370.593945
# 					name: POL1-tax_entity , total: -404,508.253233
# 					name: SWE2-factory , total: -24,367.9670622
# 					name: LUX2-distributor , total: -419,129.03347
# 					name: POL2-factory , total: -53,609.5275369
# 					name: ARG1-sales , total: -58,483.1209493
# 					name: TJK2-rd_center , total: -53,609.5275369
# 					name: FLK1-distributor , total: -4,873.59341245
# 					name: MWI2-sales , total: -43,862.340712
# 					name: NCL2-factory , total: -165,702.176023
# 					name: VAT3-sales , total: -136,460.615548
# 					name: LIE2-tax_entity , total: -165,702.176023
# 					name: LUX4-sales , total: -419,129.03347
# 					name: LKA1-distributor , total: -82,851.0880116
# 				name: 2011 , total: -13,190,537.7835
# 					name: DZA1-tax_entity , total: -217,591.351377
# 					name: GRD1-sales , total: -60,025.2003799
# 					name: DMA2-sales , total: -292,622.851852
# 					name: ARM1-factory , total: -600,252.003799
# 					name: AGO3-sales , total: -525,220.503324
# 					name: MYS3-hq , total: -570,239.403609
# 					name: NPL2-tax_entity , total: -82,534.6505223
# 					name: MAC2-factory , total: -15,006.300095
# 					name: ATF2-factory , total: -525,220.503324
# 					name: TLS3-distributor , total: -532,723.653371
# 					name: GUM2-factory , total: -255,107.101614
# 					name: ATA1-tax_entity , total: -45,018.9002849
# 					name: HND2-tax_entity , total: -727,805.554606
# 					name: COG1-tax_entity , total: -592,748.853751
# 					name: SXM3-factory , total: -157,566.150997
# 					name: HKG2-factory , total: -712,799.254511
# 					name: BFA3-distributor , total: -360,151.202279
# 					name: TON1-distributor , total: -607,755.153846
# 					name: CUW1-distributor , total: -495,207.903134
# 					name: DJI2-factory , total: -510,214.203229
# 					name: MAC1-distributor , total: -600,252.003799
# 					name: GUF1-distributor , total: -202,585.051282
# 					name: IND2-rd_center , total: -172,572.451092
# 					name: IND3-hq , total: -225,094.501424
# 					name: POL1-tax_entity , total: -457,692.152896
# 					name: LUX2-distributor , total: -37,515.7502374
# 					name: GBR1-sales , total: -45,018.9002849
# 					name: AND2-rd_center , total: -135,056.700855
# 					name: DJI3-sales , total: -637,767.754036
# 					name: ARG1-sales , total: -720,302.404558
# 					name: BES3-tax_entity , total: -195,081.901235
# 					name: MWI2-sales , total: -525,220.503324
# 					name: ISL1-factory , total: -382,660.652422
# 					name: AGO2-rd_center , total: -337,641.752137
# 					name: VAT3-sales , total: -277,616.551757
# 					name: KHM2-rd_center , total: -142,559.850902
# 					name: LUX4-sales , total: -210,088.20133
# 				name: 2035 , total: -932,664.28772
# 					name: CUW1-distributor , total: -29,668.7660857
# 					name: DMA2-sales , total: -28,908.0284938
# 					name: GRD1-sales , total: -28,147.2909018
# 					name: NER1-rd_center , total: -27,386.5533099
# 					name: ARM1-factory , total: -26,625.815718
# 					name: MYS3-hq , total: -8,748.48230733
# 					name: NPL2-tax_entity , total: -37,656.5108011
# 					name: MAC2-factory , total: -33,092.0852495
# 					name: TLS3-distributor , total: -25,104.3405341
# 					name: DZA1-tax_entity , total: -33,092.0852495
# 					name: GUM2-factory , total: -34,993.9292293
# 					name: ATA1-tax_entity , total: -13,312.907859
# 					name: GUF1-distributor , total: -21,300.6525744
# 					name: SXM3-factory , total: -30,049.1348817
# 					name: HKG2-factory , total: -33,092.0852495
# 					name: BFA3-distributor , total: -37,656.5108011
# 					name: TON1-distributor , total: -23,582.8653502
# 					name: AGO2-rd_center , total: -34,613.5604333
# 					name: DJI2-factory , total: -38,036.8795971
# 					name: JAM2-sales , total: -28,908.0284938
# 					name: CPV3-tax_entity , total: -15,595.1206348
# 					name: COG1-tax_entity , total: -32,331.3476575
# 					name: IND2-rd_center , total: -14,454.0142469
# 					name: IND3-hq , total: -34,993.9292293
# 					name: POL1-tax_entity , total: -32,331.3476575
# 					name: SWE2-factory , total: -6,466.2695315
# 					name: LUX2-distributor , total: -15,214.7518388
# 					name: POL2-factory , total: -22,061.3901663
# 					name: AND2-rd_center , total: -5,325.16314359
# 					name: DJI3-sales , total: -29,668.7660857
# 					name: TJK2-rd_center , total: -26,625.815718
# 					name: FLK1-distributor , total: -25,484.70933
# 					name: ISL1-factory , total: -17,116.5958187
# 					name: VAT3-sales , total: -18,638.0710026
# 					name: KHM2-rd_center , total: -23,963.2341462
# 					name: LUX4-sales , total: -28,908.0284938
# 					name: LKA1-distributor , total: -9,509.21989927
# 				name: 2031 , total: -399,713.266166
# 					name: DMA2-sales , total: -17,432.9773406
# 					name: GRD1-sales , total: -3,735.63800155
# 					name: DZA1-tax_entity , total: -12,274.239148
# 					name: ARM1-factory , total: -2,490.42533437
# 					name: AGO3-sales , total: -12,985.7892435
# 					name: ALA1-rd_center , total: -7,115.50095533
# 					name: LKA1-distributor , total: -17,610.8648645
# 					name: MAC2-factory , total: -16,899.3147689
# 					name: ATF2-factory , total: -4,269.3005732
# 					name: TLS3-distributor , total: -6,403.9508598
# 					name: GUM2-factory , total: -16,187.7646734
# 					name: ATA1-tax_entity , total: -7,471.2760031
# 					name: HND2-tax_entity , total: -17,610.8648645
# 					name: COD1-hq , total: -16,187.7646734
# 					name: NER1-rd_center , total: -5,158.73819262
# 					name: SXM3-factory , total: -17,788.7523883
# 					name: GBR1-sales , total: -12,807.9017196
# 					name: HKG2-factory , total: -17,432.9773406
# 					name: ISL1-factory , total: -10,139.5888614
# 					name: CUW1-distributor , total: -13,163.6767674
# 					name: DJI2-factory , total: -12,985.7892435
# 					name: CPV3-tax_entity , total: -9,428.03876582
# 					name: MAC1-distributor , total: -4,447.18809708
# 					name: GUF1-distributor , total: -2,312.53781048
# 					name: IND2-rd_center , total: -3,735.63800155
# 					name: IND3-hq , total: -15,120.4395301
# 					name: SWE2-factory , total: -6,226.06333592
# 					name: LUX2-distributor , total: -13,697.339339
# 					name: POL2-factory , total: -15,654.1021017
# 					name: DJI3-sales , total: -7,649.16352698
# 					name: ARG1-sales , total: -17,077.2022928
# 					name: FLK1-distributor , total: -17,610.8648645
# 					name: HMD1-rd_center , total: -15,298.327054
# 					name: NCL2-factory , total: -8,182.82609863
# 					name: KHM2-rd_center , total: -6,403.9508598
# 					name: LUX4-sales , total: -6,403.9508598
# 					name: NPL2-tax_entity , total: -2,312.53781048
# 			name: accrued_expenses , total: -53,561,577.6662
# 				name: 2040 , total: -399,713.266166
# 					name: CUW1-distributor , total: -9,594.65353255
# 					name: DMA2-sales , total: -14,200.0872282
# 					name: GRD1-sales , total: -14,391.9802988
# 					name: DZA1-tax_entity , total: -1,535.14456521
# 					name: ARM1-factory , total: -3,454.07527172
# 					name: AGO3-sales , total: -16,119.0179347
# 					name: MYS3-hq , total: -12,856.8357336
# 					name: NER1-rd_center , total: -6,140.57826083
# 					name: LKA1-distributor , total: -12,856.8357336
# 					name: MAC2-factory , total: -6,140.57826083
# 					name: ATF2-factory , total: -18,997.4139944
# 					name: TLS3-distributor , total: -2,302.71684781
# 					name: GUF1-distributor , total: -15,351.4456521
# 					name: HKG2-factory , total: -13,432.5149456
# 					name: BFA3-distributor , total: -18,229.8417118
# 					name: TON1-distributor , total: -9,594.65353255
# 					name: AGO2-rd_center , total: -7,291.93668474
# 					name: ALA1-rd_center , total: -2,494.60991846
# 					name: MAC1-distributor , total: -575.679211953
# 					name: COG1-tax_entity , total: -16,119.0179347
# 					name: IND2-rd_center , total: -5,948.68519018
# 					name: POL1-tax_entity , total: -13,624.4080162
# 					name: SWE2-factory , total: -17,462.2694292
# 					name: LUX2-distributor , total: -14,967.6595108
# 					name: POL2-factory , total: -12,089.263451
# 					name: AND2-rd_center , total: -14,583.8733695
# 					name: DJI3-sales , total: -3,837.86141302
# 					name: ARG1-sales , total: -17,654.1624999
# 					name: TJK2-rd_center , total: -12,473.0495923
# 					name: FLK1-distributor , total: -18,037.9486412
# 					name: MWI2-sales , total: -11,129.7980978
# 					name: ISL1-factory , total: -5,948.68519018
# 					name: HMD1-rd_center , total: -4,989.21983692
# 					name: NCL2-factory , total: -9,402.7604619
# 					name: VAT3-sales , total: -17,654.1624999
# 					name: LIE2-tax_entity , total: -7,675.72282604
# 					name: KHM2-rd_center , total: -10,554.1188858
# 				name: 2080 , total: -3,330,943.88472
# 					name: CUW1-distributor , total: -39,078.112614
# 					name: GBR1-sales , total: -128,399.512875
# 					name: NER1-rd_center , total: -93,043.1252714
# 					name: ARM1-factory , total: -143,286.412918
# 					name: MYS3-hq , total: -44,660.7001303
# 					name: NPL2-tax_entity , total: -139,564.687907
# 					name: ATF2-factory , total: -1,860.86250543
# 					name: DMA2-sales , total: -182,364.525532
# 					name: TLS3-distributor , total: -80,017.0877334
# 					name: DZA1-tax_entity , total: -104,208.300304
# 					name: GUM2-factory , total: -1,860.86250543
# 					name: ATA1-tax_entity , total: -173,060.213005
# 					name: HND2-tax_entity , total: -20,469.4875597
# 					name: COD1-hq , total: -167,477.625488
# 					name: COG1-tax_entity , total: -91,182.262766
# 					name: HKG2-factory , total: -160,034.175467
# 					name: BFA3-distributor , total: -91,182.262766
# 					name: TON1-distributor , total: -20,469.4875597
# 					name: AGO2-rd_center , total: -89,321.4002605
# 					name: JAM2-sales , total: -33,495.5250977
# 					name: CPV3-tax_entity , total: -180,503.663026
# 					name: MAC1-distributor , total: -9,304.31252714
# 					name: GUF1-distributor , total: -143,286.412918
# 					name: POL1-tax_entity , total: -24,191.2125706
# 					name: POL2-factory , total: -81,877.9502388
# 					name: AND2-rd_center , total: -80,017.0877334
# 					name: DJI3-sales , total: -135,842.962896
# 					name: ARG1-sales , total: -107,930.025315
# 					name: FLK1-distributor , total: -16,747.7625488
# 					name: TJK2-rd_center , total: -80,017.0877334
# 					name: MWI2-sales , total: -48,382.4251411
# 					name: HMD1-rd_center , total: -180,503.663026
# 					name: NCL2-factory , total: -91,182.262766
# 					name: LIE2-tax_entity , total: -148,869.000434
# 					name: KHM2-rd_center , total: -48,382.4251411
# 					name: LUX4-sales , total: -147,008.137929
# 					name: LKA1-distributor , total: -1,860.86250543
# 				name: 2049 , total: -12,924,062.2727
# 					name: GBR1-sales , total: -522,251.109741
# 					name: GRD1-sales , total: -390,035.63892
# 					name: NER1-rd_center , total: -555,304.977446
# 					name: ARM1-factory , total: -601,580.392233
# 					name: AGO3-sales , total: -264,430.941641
# 					name: LKA1-distributor , total: -323,927.90351
# 					name: MAC2-factory , total: -112,383.150197
# 					name: ATF2-factory , total: -323,927.90351
# 					name: TLS3-distributor , total: -343,760.224133
# 					name: DZA1-tax_entity , total: -52,886.1883282
# 					name: GUM2-factory , total: -528,861.883282
# 					name: ATA1-tax_entity , total: -396,646.412461
# 					name: COD1-hq , total: -59,496.9618692
# 					name: GUF1-distributor , total: -608,191.165774
# 					name: SXM3-factory , total: -52,886.1883282
# 					name: HKG2-factory , total: -442,921.827248
# 					name: BFA3-distributor , total: -171,880.112067
# 					name: TON1-distributor , total: -204,933.979772
# 					name: MAC1-distributor , total: -502,418.789118
# 					name: COG1-tax_entity , total: -165,269.338526
# 					name: IND2-rd_center , total: -271,041.715182
# 					name: IND3-hq , total: -442,921.827248
# 					name: POL1-tax_entity , total: -594,969.618692
# 					name: SWE2-factory , total: -6,610.77354102
# 					name: LUX2-distributor , total: -224,766.300395
# 					name: POL2-factory , total: -608,191.165774
# 					name: AND2-rd_center , total: -482,586.468495
# 					name: DJI3-sales , total: -218,155.526854
# 					name: ARG1-sales , total: -535,472.656823
# 					name: BES3-tax_entity , total: -475,975.694954
# 					name: TJK2-rd_center , total: -251,209.394559
# 					name: HMD1-rd_center , total: -528,861.883282
# 					name: NCL2-factory , total: -628,023.486397
# 					name: VAT3-sales , total: -489,197.242036
# 					name: LIE2-tax_entity , total: -13,221.547082
# 					name: KHM2-rd_center , total: -363,592.544756
# 					name: LUX4-sales , total: -165,269.338526
# 				name: 2090 , total: -12,924,062.2727
# 					name: DZA1-tax_entity , total: -456,704.73221
# 					name: GRD1-sales , total: -54,531.9083236
# 					name: GBR1-sales , total: -265,843.053078
# 					name: ARM1-factory , total: -299,925.49578
# 					name: AGO3-sales , total: -102,247.328107
# 					name: ALA1-rd_center , total: -668,015.876964
# 					name: MYS3-hq , total: -368,090.381184
# 					name: NER1-rd_center , total: -224,944.121835
# 					name: LKA1-distributor , total: -279,476.030159
# 					name: MAC2-factory , total: -374,906.869725
# 					name: ATF2-factory , total: -54,531.9083236
# 					name: TLS3-distributor , total: -320,374.961401
# 					name: GUM2-factory , total: -224,944.121835
# 					name: HND2-tax_entity , total: -20,449.4656214
# 					name: GUF1-distributor , total: -558,952.060317
# 					name: FLK1-distributor , total: -449,888.24367
# 					name: SXM3-factory , total: -109,063.816647
# 					name: BFA3-distributor , total: -218,127.633294
# 					name: TON1-distributor , total: -606,667.4801
# 					name: DJI2-factory , total: -511,236.640534
# 					name: CPV3-tax_entity , total: -538,502.594696
# 					name: MAC1-distributor , total: -449,888.24367
# 					name: COG1-tax_entity , total: -429,438.778048
# 					name: SWE2-factory , total: -170,412.213511
# 					name: LUX2-distributor , total: -388,539.846806
# 					name: POL2-factory , total: -661,199.388424
# 					name: AND2-rd_center , total: -490,787.174913
# 					name: ARG1-sales , total: -381,723.358265
# 					name: BES3-tax_entity , total: -463,521.220751
# 					name: TJK2-rd_center , total: -402,172.823887
# 					name: MWI2-sales , total: -606,667.4801
# 					name: ISL1-factory , total: -429,438.778048
# 					name: HMD1-rd_center , total: -368,090.381184
# 					name: NCL2-factory , total: -177,228.702052
# 					name: LIE2-tax_entity , total: -395,356.335346
# 					name: KHM2-rd_center , total: -20,449.4656214
# 					name: LUX4-sales , total: -381,723.358265
# 				name: 2093 , total: -5,995,698.99249
# 					name: DZA1-tax_entity , total: -13,878.932853
# 					name: GBR1-sales , total: -312,275.989192
# 					name: AGO3-sales , total: -138,789.32853
# 					name: MYS3-hq , total: -256,760.25778
# 					name: MAC2-factory , total: -121,440.662464
# 					name: ATF2-factory , total: -208,183.992795
# 					name: DMA2-sales , total: -24,288.1324927
# 					name: TLS3-distributor , total: -138,789.32853
# 					name: GUM2-factory , total: -176,956.393876
# 					name: COD1-hq , total: -194,305.059942
# 					name: NER1-rd_center , total: -166,547.194236
# 					name: FLK1-distributor , total: -17,348.6660662
# 					name: SXM3-factory , total: -183,895.860302
# 					name: HKG2-factory , total: -163,077.461023
# 					name: BFA3-distributor , total: -90,213.0635444
# 					name: TON1-distributor , total: -235,941.858501
# 					name: ALA1-rd_center , total: -308,806.255979
# 					name: JAM2-sales , total: -145,728.794956
# 					name: GUF1-distributor , total: -225,532.658861
# 					name: IND2-rd_center , total: -97,152.5299709
# 					name: IND3-hq , total: -194,305.059942
# 					name: POL1-tax_entity , total: -6,939.46642649
# 					name: COG1-tax_entity , total: -281,048.390273
# 					name: LUX2-distributor , total: -72,864.3974782
# 					name: POL2-factory , total: -298,397.056339
# 					name: AND2-rd_center , total: -284,518.123486
# 					name: DJI3-sales , total: -156,137.994596
# 					name: ARG1-sales , total: -76,334.1306914
# 					name: BES3-tax_entity , total: -145,728.794956
# 					name: TJK2-rd_center , total: -117,970.92925
# 					name: MWI2-sales , total: -274,108.923846
# 					name: ISL1-factory , total: -281,048.390273
# 					name: HMD1-rd_center , total: -97,152.5299709
# 					name: NCL2-factory , total: -322,685.188832
# 					name: VAT3-sales , total: -45,106.5317722
# 					name: LIE2-tax_entity , total: -93,682.7967576
# 					name: LUX4-sales , total: -27,757.865706
# 				name: 2071 , total: -9,859,593.89876
# 					name: DMA2-sales , total: -292,424.930265
# 					name: DZA1-tax_entity , total: -204,697.451185
# 					name: ARM1-factory , total: -204,697.451185
# 					name: AGO3-sales , total: -263,182.437238
# 					name: MYS3-hq , total: -307,046.176778
# 					name: LKA1-distributor , total: -331,414.920967
# 					name: MAC2-factory , total: -180,328.706997
# 					name: ATF2-factory , total: -414,268.651208
# 					name: ATA1-tax_entity , total: -263,182.437238
# 					name: HND2-tax_entity , total: -394,773.655857
# 					name: COD1-hq , total: -238,813.69305
# 					name: SXM3-factory , total: -404,521.153533
# 					name: HKG2-factory , total: -414,268.651208
# 					name: TON1-distributor , total: -389,899.90702
# 					name: CUW1-distributor , total: -472,753.637261
# 					name: ALA1-rd_center , total: -302,172.42794
# 					name: JAM2-sales , total: -243,687.441887
# 					name: CPV3-tax_entity , total: -92,601.2279172
# 					name: MAC1-distributor , total: -248,561.190725
# 					name: COG1-tax_entity , total: -443,511.144235
# 					name: IND2-rd_center , total: -297,298.679102
# 					name: IND3-hq , total: -82,853.7302417
# 					name: POL1-tax_entity , total: -209,571.200023
# 					name: SWE2-factory , total: -43,863.7395397
# 					name: LUX2-distributor , total: -307,046.176778
# 					name: POL2-factory , total: -346,036.16748
# 					name: AND2-rd_center , total: -121,843.720944
# 					name: DJI3-sales , total: -458,132.390748
# 					name: BES3-tax_entity , total: -424,016.148884
# 					name: FLK1-distributor , total: -307,046.176778
# 					name: MWI2-sales , total: -443,511.144235
# 					name: ISL1-factory , total: -258,308.6884
# 					name: HMD1-rd_center , total: -34,116.2418642
# 					name: NCL2-factory , total: -43,863.7395397
# 					name: KHM2-rd_center , total: -107,222.47443
# 					name: LUX4-sales , total: -204,697.451185
# 					name: NPL2-tax_entity , total: -63,358.7348907
# 				name: 2085 , total: -133,237.755389
# 					name: DZA1-tax_entity , total: -5,982.10330316
# 					name: NER1-rd_center , total: -5,030.40505039
# 					name: ARM1-factory , total: -2,107.33184543
# 					name: AGO3-sales , total: -747.762912895
# 					name: DJI2-factory , total: -3,534.8792246
# 					name: MYS3-hq , total: -3,738.81456448
# 					name: LKA1-distributor , total: -4,010.72835098
# 					name: MAC2-factory , total: -611.806019642
# 					name: ATF2-factory , total: -6,525.93087618
# 					name: COG1-tax_entity , total: -3,466.90077797
# 					name: FLK1-distributor , total: -5,982.10330316
# 					name: GBR1-sales , total: -4,894.44815713
# 					name: HKG2-factory , total: -543.827573015
# 					name: BFA3-distributor , total: -475.849126388
# 					name: DMA2-sales , total: -5,098.38349701
# 					name: CUW1-distributor , total: -815.741359522
# 					name: ALA1-rd_center , total: -4,554.555924
# 					name: CPV3-tax_entity , total: -1,563.50427242
# 					name: MAC1-distributor , total: -3,602.85767122
# 					name: GUF1-distributor , total: -611.806019642
# 					name: IND2-rd_center , total: -611.806019642
# 					name: IND3-hq , total: -543.827573015
# 					name: SWE2-factory , total: -3,602.85767122
# 					name: LUX2-distributor , total: -4,826.46971051
# 					name: POL2-factory , total: -4,826.46971051
# 					name: AND2-rd_center , total: -2,379.24563194
# 					name: DJI3-sales , total: -6,457.95242955
# 					name: ARG1-sales , total: -4,078.70679761
# 					name: BES3-tax_entity , total: -3,942.74990436
# 					name: TJK2-rd_center , total: -4,622.53437063
# 					name: TON1-distributor , total: -4,214.66369086
# 					name: HMD1-rd_center , total: -6,457.95242955
# 					name: NCL2-factory , total: -5,982.10330316
# 					name: VAT3-sales , total: -6,729.86621606
# 					name: LIE2-tax_entity , total: -747.762912895
# 					name: LUX4-sales , total: -4,554.555924
# 					name: NPL2-tax_entity , total: -4,758.49126388
# 				name: 2038 , total: -7,994,265.32332
# 					name: GBR1-sales , total: -52,193.2447659
# 					name: GRD1-sales , total: -252,267.349702
# 					name: DMA2-sales , total: -326,207.779787
# 					name: ARM1-factory , total: -317,508.90566
# 					name: AGO3-sales , total: -4,349.43706383
# 					name: MYS3-hq , total: -400,148.209872
# 					name: LKA1-distributor , total: -347,954.965106
# 					name: MAC2-factory , total: -317,508.90566
# 					name: ATF2-factory , total: -43,494.3706383
# 					name: TLS3-distributor , total: -274,014.535021
# 					name: GUM2-factory , total: -21,747.1853191
# 					name: HND2-tax_entity , total: -121,784.237787
# 					name: COD1-hq , total: -113,085.36366
# 					name: COG1-tax_entity , total: -26,096.622383
# 					name: FLK1-distributor , total: -391,449.335745
# 					name: SXM3-factory , total: -260,966.22383
# 					name: HKG2-factory , total: -308,810.031532
# 					name: BFA3-distributor , total: -30,446.0594468
# 					name: ISL1-factory , total: -52,193.2447659
# 					name: JAM2-sales , total: -282,713.409149
# 					name: MAC1-distributor , total: -204,423.542
# 					name: GUF1-distributor , total: -39,144.9335745
# 					name: POL1-tax_entity , total: -4,349.43706383
# 					name: SWE2-factory , total: -347,954.965106
# 					name: LUX2-distributor , total: -239,219.038511
# 					name: POL2-factory , total: -265,315.660894
# 					name: AND2-rd_center , total: -365,352.713362
# 					name: DJI3-sales , total: -369,702.150425
# 					name: ARG1-sales , total: -265,315.660894
# 					name: TJK2-rd_center , total: -295,761.72034
# 					name: BES3-tax_entity , total: -95,687.6154042
# 					name: MWI2-sales , total: -95,687.6154042
# 					name: TON1-distributor , total: -69,590.9930213
# 					name: HMD1-rd_center , total: -417,545.958128
# 					name: VAT3-sales , total: -334,906.653915
# 					name: KHM2-rd_center , total: -295,761.72034
# 					name: LUX4-sales , total: -343,605.528042
# 			name: liab_for_sale , total: -28,026,406.9184
# 				name: 2123 , total: -3,380,069.17609
# 					name: GBR1-sales , total: -66,751.8149676
# 					name: GRD1-sales , total: -26,296.1695327
# 					name: NER1-rd_center , total: -76,865.7263263
# 					name: ARM1-factory , total: -40,455.6454349
# 					name: AGO3-sales , total: -76,865.7263263
# 					name: ALA1-rd_center , total: -143,617.541294
# 					name: NPL2-tax_entity , total: -82,934.0731415
# 					name: MAC2-factory , total: -6,068.34681523
# 					name: ATF2-factory , total: -78,888.508598
# 					name: DMA2-sales , total: -139,571.97675
# 					name: DZA1-tax_entity , total: -30,341.7340762
# 					name: ATA1-tax_entity , total: -182,050.404457
# 					name: HND2-tax_entity , total: -12,136.6936305
# 					name: COG1-tax_entity , total: -54,615.1213371
# 					name: HKG2-factory , total: -200,255.444903
# 					name: BFA3-distributor , total: -93,047.9845003
# 					name: ISL1-factory , total: -82,934.0731415
# 					name: CUW1-distributor , total: -62,706.2504241
# 					name: DJI2-factory , total: -52,592.3390654
# 					name: JAM2-sales , total: -44,501.2099784
# 					name: CPV3-tax_entity , total: -178,004.839914
# 					name: MAC1-distributor , total: -103,161.895859
# 					name: GUF1-distributor , total: -10,113.9113587
# 					name: IND2-rd_center , total: -184,073.186729
# 					name: IND3-hq , total: -161,822.58174
# 					name: POL1-tax_entity , total: -4,045.56454349
# 					name: LUX2-distributor , total: -80,911.2908698
# 					name: POL2-factory , total: -50,569.5567936
# 					name: DJI3-sales , total: -89,002.4199568
# 					name: ARG1-sales , total: -26,296.1695327
# 					name: TJK2-rd_center , total: -123,389.718576
# 					name: MWI2-sales , total: -173,959.27537
# 					name: TON1-distributor , total: -30,341.7340762
# 					name: HMD1-rd_center , total: -155,754.234924
# 					name: AGO2-rd_center , total: -200,255.444903
# 					name: NCL2-factory , total: -192,164.315816
# 					name: LIE2-tax_entity , total: -62,706.2504241
# 				name: 2135 , total: -3,168,814.85258
# 					name: CUW1-distributor , total: -153,757.329712
# 					name: DZA1-tax_entity , total: -67,158.3738974
# 					name: GRD1-sales , total: -58,321.745753
# 					name: GBR1-sales , total: -116,643.491506
# 					name: AGO3-sales , total: -86,598.9558151
# 					name: ALA1-rd_center , total: -144,920.701568
# 					name: MYS3-hq , total: -74,227.6764129
# 					name: LKA1-distributor , total: -146,688.027197
# 					name: MAC2-factory , total: -111,341.514619
# 					name: ATF2-factory , total: -26,509.8844332
# 					name: GUM2-factory , total: -90,133.6070728
# 					name: ATA1-tax_entity , total: -60,089.0713819
# 					name: HND2-tax_entity , total: -81,296.9789284
# 					name: COG1-tax_entity , total: -10,603.9537733
# 					name: FLK1-distributor , total: -90,133.6070728
# 					name: SXM3-factory , total: -58,321.745753
# 					name: BFA3-distributor , total: -68,925.6995263
# 					name: DMA2-sales , total: -51,252.4432375
# 					name: AGO2-rd_center , total: -19,440.5819177
# 					name: DJI2-factory , total: -102,504.886475
# 					name: JAM2-sales , total: -146,688.027197
# 					name: CPV3-tax_entity , total: -33,579.1869487
# 					name: MAC1-distributor , total: -77,762.3276707
# 					name: GUF1-distributor , total: -84,831.6301862
# 					name: IND3-hq , total: -109,574.18899
# 					name: SWE2-factory , total: -54,787.0944952
# 					name: LUX2-distributor , total: -111,341.514619
# 					name: AND2-rd_center , total: -136,084.073424
# 					name: DJI3-sales , total: -90,133.6070728
# 					name: ARG1-sales , total: -97,202.9095883
# 					name: TJK2-rd_center , total: -24,742.5588043
# 					name: BES3-tax_entity , total: -118,410.817135
# 					name: MWI2-sales , total: -107,806.863362
# 					name: NCL2-factory , total: -56,554.4201241
# 					name: VAT3-sales , total: -150,222.678455
# 					name: LIE2-tax_entity , total: -148,455.352826
# 					name: LUX4-sales , total: -1,767.32562888
# 				name: 2124 , total: -3,098,396.74474
# 					name: CUW1-distributor , total: -162,730.921468
# 					name: DMA2-sales , total: -45,564.658011
# 					name: GRD1-sales , total: -94,383.9344513
# 					name: NER1-rd_center , total: -32,546.1842935
# 					name: ARM1-factory , total: -100,893.17131
# 					name: AGO3-sales , total: -9,763.85528806
# 					name: NPL2-tax_entity , total: -22,782.3290055
# 					name: MAC2-factory , total: -135,066.664818
# 					name: ATF2-factory , total: -151,339.756965
# 					name: TLS3-distributor , total: -60,210.440943
# 					name: GUM2-factory , total: -97,638.5528806
# 					name: HND2-tax_entity , total: -131,812.046389
# 					name: COD1-hq , total: -157,848.993824
# 					name: GUF1-distributor , total: -26,036.9474348
# 					name: SXM3-factory , total: -26,036.9474348
# 					name: HKG2-factory , total: -126,930.118745
# 					name: BFA3-distributor , total: -76,483.5330898
# 					name: ISL1-factory , total: -56,955.8225137
# 					name: AGO2-rd_center , total: -32,546.1842935
# 					name: ALA1-rd_center , total: -11,391.1645027
# 					name: JAM2-sales , total: -138,321.283248
# 					name: MAC1-distributor , total: -131,812.046389
# 					name: COG1-tax_entity , total: -144,830.520106
# 					name: IND3-hq , total: -102,520.480525
# 					name: POL1-tax_entity , total: -159,476.303038
# 					name: LUX2-distributor , total: -52,073.8948697
# 					name: POL2-factory , total: -135,066.664818
# 					name: DJI3-sales , total: -37,428.1119376
# 					name: FLK1-distributor , total: -84,620.0791632
# 					name: MWI2-sales , total: -11,391.1645027
# 					name: TON1-distributor , total: -3,254.61842935
# 					name: HMD1-rd_center , total: -74,856.2238751
# 					name: NCL2-factory , total: -107,402.408169
# 					name: VAT3-sales , total: -61,837.7501577
# 					name: LIE2-tax_entity , total: -50,446.585655
# 					name: KHM2-rd_center , total: -122,048.191101
# 					name: LUX4-sales , total: -122,048.191101
# 				name: 2097 , total: -704,181.078351
# 					name: DZA1-tax_entity , total: -5,297.43960071
# 					name: GRD1-sales , total: -28,000.7521752
# 					name: NER1-rd_center , total: -20,054.5927741
# 					name: ARM1-factory , total: -13,243.5990018
# 					name: AGO3-sales , total: -35,946.9115762
# 					name: TJK2-rd_center , total: -9,081.32502978
# 					name: LKA1-distributor , total: -30,649.4719755
# 					name: MAC2-factory , total: -34,811.7459475
# 					name: ATF2-factory , total: -32,163.0261471
# 					name: TLS3-distributor , total: -24,216.8667461
# 					name: GUM2-factory , total: -36,325.3001191
# 					name: ATA1-tax_entity , total: -21,946.5354886
# 					name: HND2-tax_entity , total: -6,054.21668652
# 					name: COD1-hq , total: -12,108.433373
# 					name: GBR1-sales , total: -1,891.94271454
# 					name: HKG2-factory , total: -9,838.1021156
# 					name: BFA3-distributor , total: -14,000.3760876
# 					name: DMA2-sales , total: -32,163.0261471
# 					name: CUW1-distributor , total: -12,108.433373
# 					name: DJI2-factory , total: -3,405.49688617
# 					name: MAC1-distributor , total: -9,838.1021156
# 					name: COG1-tax_entity , total: -20,054.5927741
# 					name: IND3-hq , total: -7,189.38231525
# 					name: POL1-tax_entity , total: -15,135.5417163
# 					name: SWE2-factory , total: -6,054.21668652
# 					name: LUX2-distributor , total: -11,351.6562872
# 					name: POL2-factory , total: -20,432.981317
# 					name: AND2-rd_center , total: -13,243.5990018
# 					name: DJI3-sales , total: -37,460.4657479
# 					name: ARG1-sales , total: -30,649.4719755
# 					name: FLK1-distributor , total: -24,973.6438319
# 					name: BES3-tax_entity , total: -22,703.3125745
# 					name: ISL1-factory , total: -3,027.10834326
# 					name: HMD1-rd_center , total: -13,621.9875447
# 					name: NCL2-factory , total: -29,135.9178039
# 					name: VAT3-sales , total: -22,703.3125745
# 					name: LIE2-tax_entity , total: -33,298.1917759
# 				name: 2193 , total: -6,126,375.38165
# 					name: AGO2-rd_center , total: -113,451.395957
# 					name: GRD1-sales , total: -197,729.57581
# 					name: GBR1-sales , total: -64,829.369118
# 					name: ARM1-factory , total: -226,902.791913
# 					name: AGO3-sales , total: -149,107.548971
# 					name: NPL2-tax_entity , total: -12,965.8738236
# 					name: DMA2-sales , total: -230,144.260369
# 					name: TLS3-distributor , total: -188,005.170442
# 					name: GUM2-factory , total: -256,076.008016
# 					name: HND2-tax_entity , total: -314,422.440222
# 					name: COD1-hq , total: -97,244.0536771
# 					name: FLK1-distributor , total: -262,558.944928
# 					name: SXM3-factory , total: -165,314.891251
# 					name: HKG2-factory , total: -230,144.260369
# 					name: BFA3-distributor , total: -168,556.359707
# 					name: TON1-distributor , total: -181,522.233531
# 					name: CUW1-distributor , total: -217,178.386545
# 					name: DJI2-factory , total: -139,383.143604
# 					name: JAM2-sales , total: -204,212.512722
# 					name: MAC1-distributor , total: -249,593.071104
# 					name: GUF1-distributor , total: -139,383.143604
# 					name: IND2-rd_center , total: -22,690.2791913
# 					name: IND3-hq , total: -48,622.0268385
# 					name: SWE2-factory , total: -77,795.2429416
# 					name: LUX2-distributor , total: -175,039.296619
# 					name: POL2-factory , total: -213,936.91809
# 					name: AND2-rd_center , total: -132,900.206692
# 					name: DJI3-sales , total: -48,622.0268385
# 					name: ARG1-sales , total: -171,797.828163
# 					name: TJK2-rd_center , total: -320,905.377134
# 					name: BES3-tax_entity , total: -77,795.2429416
# 					name: MWI2-sales , total: -272,283.350296
# 					name: HMD1-rd_center , total: -178,280.765075
# 					name: VAT3-sales , total: -29,173.2161031
# 					name: LIE2-tax_entity , total: -314,422.440222
# 					name: LUX4-sales , total: -68,070.8375739
# 					name: LKA1-distributor , total: -165,314.891251
# 				name: 2175 , total: -5,703,866.73464
# 					name: GBR1-sales , total: -268,985.25109
# 					name: GRD1-sales , total: -68,970.5772025
# 					name: NER1-rd_center , total: -341,404.357152
# 					name: ARM1-factory , total: -182,772.029587
# 					name: DJI2-factory , total: -210,360.260468
# 					name: MYS3-hq , total: -186,220.558447
# 					name: ATF2-factory , total: -13,794.1154405
# 					name: TLS3-distributor , total: -255,191.135649
# 					name: ATA1-tax_entity , total: -34,485.2886012
# 					name: HND2-tax_entity , total: -182,772.029587
# 					name: COD1-hq , total: -79,316.1637828
# 					name: COG1-tax_entity , total: -210,360.260468
# 					name: BES3-tax_entity , total: -172,426.443006
# 					name: BFA3-distributor , total: -158,632.327566
# 					name: ISL1-factory , total: -48,279.4040417
# 					name: CUW1-distributor , total: -303,470.539691
# 					name: ALA1-rd_center , total: -48,279.4040417
# 					name: JAM2-sales , total: -141,389.683265
# 					name: CPV3-tax_entity , total: -79,316.1637828
# 					name: MAC1-distributor , total: -103,455.865804
# 					name: GUF1-distributor , total: -213,808.789328
# 					name: IND2-rd_center , total: -200,014.673887
# 					name: POL1-tax_entity , total: -37,933.8174614
# 					name: SWE2-factory , total: -75,867.6349227
# 					name: LUX2-distributor , total: -10,345.5865804
# 					name: POL2-factory , total: -337,955.828292
# 					name: AND2-rd_center , total: -37,933.8174614
# 					name: DJI3-sales , total: -127,595.567825
# 					name: ARG1-sales , total: -227,602.904768
# 					name: TJK2-rd_center , total: -262,088.193369
# 					name: FLK1-distributor , total: -96,558.8080835
# 					name: MWI2-sales , total: -141,389.683265
# 					name: HMD1-rd_center , total: -272,433.77995
# 					name: NCL2-factory , total: -310,367.597411
# 					name: VAT3-sales , total: -75,867.6349227
# 					name: KHM2-rd_center , total: -6,897.05772025
# 					name: LUX4-sales , total: -179,323.500726
# 				name: 2098 , total: -2,253,379.45072
# 					name: DZA1-tax_entity , total: -69,987.8546304
# 					name: GBR1-sales , total: -34,420.2563756
# 					name: AGO3-sales , total: -74,577.2221472
# 					name: MYS3-hq , total: -32,125.5726172
# 					name: NPL2-tax_entity , total: -113,586.84604
# 					name: MAC2-factory , total: -9,178.7350335
# 					name: ATF2-factory , total: -67,693.170872
# 					name: DMA2-sales , total: -90,640.0084558
# 					name: TLS3-distributor , total: -52,777.7264426
# 					name: GUM2-factory , total: -13,768.1025502
# 					name: GUF1-distributor , total: -66,545.8289929
# 					name: HND2-tax_entity , total: -108,997.478523
# 					name: COD1-hq , total: -60,809.1195969
# 					name: NER1-rd_center , total: -3,442.02563756
# 					name: SXM3-factory , total: -49,335.700805
# 					name: BFA3-distributor , total: -95,229.3759725
# 					name: TON1-distributor , total: -88,345.3246974
# 					name: AGO2-rd_center , total: -91,787.350335
# 					name: ALA1-rd_center , total: -68,840.5127512
# 					name: JAM2-sales , total: -18,357.470067
# 					name: CPV3-tax_entity , total: -112,439.50416
# 					name: MAC1-distributor , total: -47,041.0170467
# 					name: COG1-tax_entity , total: -73,429.880268
# 					name: IND3-hq , total: -75,724.5640264
# 					name: POL1-tax_entity , total: -3,442.02563756
# 					name: POL2-factory , total: -57,367.0939594
# 					name: AND2-rd_center , total: -92,934.6922142
# 					name: DJI3-sales , total: -52,777.7264426
# 					name: ARG1-sales , total: -60,809.1195969
# 					name: BES3-tax_entity , total: -13,768.1025502
# 					name: TJK2-rd_center , total: -53,925.0683218
# 					name: MWI2-sales , total: -10,326.0769127
# 					name: ISL1-factory , total: -105,555.452885
# 					name: HMD1-rd_center , total: -28,683.5469797
# 					name: VAT3-sales , total: -114,734.187919
# 					name: KHM2-rd_center , total: -92,934.6922142
# 					name: LUX4-sales , total: -47,041.0170467
# 				name: 2148 , total: -3,591,323.49959
# 					name: DZA1-tax_entity , total: -33,144.6794208
# 					name: GRD1-sales , total: -54,591.236693
# 					name: DMA2-sales , total: -72,138.4199158
# 					name: MYS3-hq , total: -40,943.4275198
# 					name: LKA1-distributor , total: -130,629.030658
# 					name: TLS3-distributor , total: -35,094.3664455
# 					name: GUM2-factory , total: -66,289.3588415
# 					name: ATA1-tax_entity , total: -171,572.458178
# 					name: HND2-tax_entity , total: -159,874.33603
# 					name: COD1-hq , total: -161,824.023054
# 					name: SXM3-factory , total: -3,899.3740495
# 					name: GBR1-sales , total: -13,647.8091733
# 					name: BES3-tax_entity , total: -23,396.244297
# 					name: BFA3-distributor , total: -99,434.0382623
# 					name: TON1-distributor , total: -134,528.404708
# 					name: HKG2-factory , total: -29,245.3053713
# 					name: CUW1-distributor , total: -179,371.206277
# 					name: DJI2-factory , total: -56,540.9237178
# 					name: JAM2-sales , total: -150,125.900906
# 					name: CPV3-tax_entity , total: -21,446.5572723
# 					name: MAC1-distributor , total: -116,981.221485
# 					name: GUF1-distributor , total: -23,396.244297
# 					name: IND2-rd_center , total: -155,974.96198
# 					name: IND3-hq , total: -142,327.152807
# 					name: SWE2-factory , total: -163,773.710079
# 					name: LUX2-distributor , total: -105,283.099337
# 					name: POL2-factory , total: -155,974.96198
# 					name: AND2-rd_center , total: -109,182.473386
# 					name: TJK2-rd_center , total: -1,949.68702475
# 					name: FLK1-distributor , total: -152,075.587931
# 					name: ISL1-factory , total: -85,786.229089
# 					name: HMD1-rd_center , total: -111,132.160411
# 					name: AGO2-rd_center , total: -40,943.4275198
# 					name: NCL2-factory , total: -175,471.832228
# 					name: LIE2-tax_entity , total: -187,169.954376
# 					name: KHM2-rd_center , total: -81,886.8550395
# 					name: NPL2-tax_entity , total: -144,276.839832
# 			name: other_liab , total: -19,929,889.3642
# 				name: 2299 , total: -2,079,199.65377
# 					name: GBR1-sales , total: -15,956.0776263
# 					name: GRD1-sales , total: -3,682.17175992
# 					name: DZA1-tax_entity , total: -93,281.6845847
# 					name: ARM1-factory , total: -11,046.5152798
# 					name: AGO3-sales , total: -56,459.9669855
# 					name: DJI2-factory , total: -117,829.496317
# 					name: MYS3-hq , total: -40,503.8893591
# 					name: NPL2-tax_entity , total: -63,824.3105053
# 					name: MAC2-factory , total: -44,186.0611191
# 					name: ATF2-factory , total: -51,550.4046389
# 					name: TLS3-distributor , total: -18,410.8587996
# 					name: GUM2-factory , total: -20,865.6399729
# 					name: HND2-tax_entity , total: -38,049.1081859
# 					name: COD1-hq , total: -2,454.78117328
# 					name: NER1-rd_center , total: -96,963.8563446
# 					name: SXM3-factory , total: -14,728.6870397
# 					name: HKG2-factory , total: -98,191.2469312
# 					name: BFA3-distributor , total: -12,273.9058664
# 					name: DMA2-sales , total: -61,369.529332
# 					name: CUW1-distributor , total: -18,410.8587996
# 					name: ALA1-rd_center , total: -65,051.701092
# 					name: JAM2-sales , total: -88,372.1222381
# 					name: GUF1-distributor , total: -41,731.2799458
# 					name: IND3-hq , total: -92,054.293998
# 					name: POL1-tax_entity , total: -115,374.715144
# 					name: SWE2-factory , total: -84,689.9504782
# 					name: POL2-factory , total: -85,917.3410648
# 					name: AND2-rd_center , total: -52,777.7952255
# 					name: ARG1-sales , total: -67,506.4822652
# 					name: TJK2-rd_center , total: -71,188.6540252
# 					name: MWI2-sales , total: -61,369.529332
# 					name: TON1-distributor , total: -117,829.496317
# 					name: NCL2-factory , total: -22,093.0305595
# 					name: VAT3-sales , total: -14,728.6870397
# 					name: LIE2-tax_entity , total: -117,829.496317
# 					name: LUX4-sales , total: -3,682.17175992
# 					name: LKA1-distributor , total: -96,963.8563446
# 				name: 2315 , total: -2,003,131.37375
# 					name: DZA1-tax_entity , total: -7,325.97681101
# 					name: GBR1-sales , total: -36,629.884055
# 					name: AGO3-sales , total: -56,514.6782564
# 					name: NER1-rd_center , total: -84,772.0173845
# 					name: LKA1-distributor , total: -60,700.9507198
# 					name: MAC2-factory , total: -20,931.3623172
# 					name: ATF2-factory , total: -75,352.9043418
# 					name: ATA1-tax_entity , total: -103,610.24347
# 					name: HND2-tax_entity , total: -11,512.2492744
# 					name: COD1-hq , total: -64,887.2231832
# 					name: GUF1-distributor , total: -68,026.9275308
# 					name: SXM3-factory , total: -97,330.8347748
# 					name: HKG2-factory , total: -68,026.9275308
# 					name: BFA3-distributor , total: -34,536.7478233
# 					name: TON1-distributor , total: -36,629.884055
# 					name: AGO2-rd_center , total: -33,490.1797075
# 					name: ALA1-rd_center , total: -66,980.3594149
# 					name: JAM2-sales , total: -32,443.6115916
# 					name: CPV3-tax_entity , total: -27,210.7710123
# 					name: COG1-tax_entity , total: -100,470.539122
# 					name: IND2-rd_center , total: -23,024.4985489
# 					name: IND3-hq , total: -55,468.1101405
# 					name: POL1-tax_entity , total: -102,563.675354
# 					name: SWE2-factory , total: -66,980.3594149
# 					name: LUX2-distributor , total: -6,279.40869515
# 					name: POL2-factory , total: -42,909.2927502
# 					name: AND2-rd_center , total: -92,097.9941956
# 					name: DJI3-sales , total: -45,002.4289819
# 					name: ARG1-sales , total: -99,423.9710066
# 					name: TJK2-rd_center , total: -25,117.6347806
# 					name: FLK1-distributor , total: -33,490.1797075
# 					name: HMD1-rd_center , total: -79,539.1768052
# 					name: NCL2-factory , total: -55,468.1101405
# 					name: VAT3-sales , total: -54,421.5420246
# 					name: LIE2-tax_entity , total: -63,840.6550674
# 					name: KHM2-rd_center , total: -4,186.27246343
# 					name: NPL2-tax_entity , total: -65,933.7912991
# 				name: 2270 , total: -1,876,350.90706
# 					name: AGO2-rd_center , total: -90,670.7374077
# 					name: GRD1-sales , total: -12,800.5746928
# 					name: GBR1-sales , total: -41,601.8677518
# 					name: ARM1-factory , total: -97,071.0247541
# 					name: AGO3-sales , total: -14,934.0038083
# 					name: MYS3-hq , total: -3,200.14367321
# 					name: LKA1-distributor , total: -42,668.5823095
# 					name: MAC2-factory , total: -28,801.2930589
# 					name: ATF2-factory , total: -37,335.0095208
# 					name: DMA2-sales , total: -6,400.28734642
# 					name: TLS3-distributor , total: -22,401.0057125
# 					name: DZA1-tax_entity , total: -26,667.8639434
# 					name: GUM2-factory , total: -50,135.5842137
# 					name: ATA1-tax_entity , total: -17,067.4329238
# 					name: COD1-hq , total: -43,735.2968672
# 					name: NER1-rd_center , total: -45,868.7259827
# 					name: HKG2-factory , total: -10,667.1455774
# 					name: ISL1-factory , total: -68,269.7316952
# 					name: CUW1-distributor , total: -59,736.0152333
# 					name: ALA1-rd_center , total: -13,867.2892506
# 					name: CPV3-tax_entity , total: -67,203.0171375
# 					name: MAC1-distributor , total: -19,200.8620393
# 					name: COG1-tax_entity , total: -83,203.7355035
# 					name: IND3-hq , total: -37,335.0095208
# 					name: GUF1-distributor , total: -57,602.5861178
# 					name: POL1-tax_entity , total: -100,271.168427
# 					name: LUX2-distributor , total: -4,266.85823095
# 					name: AND2-rd_center , total: -68,269.7316952
# 					name: DJI3-sales , total: -91,737.4519654
# 					name: BES3-tax_entity , total: -76,803.4481571
# 					name: FLK1-distributor , total: -73,603.3044839
# 					name: MWI2-sales , total: -102,404.597543
# 					name: TJK2-rd_center , total: -99,204.4538696
# 					name: HMD1-rd_center , total: -104,538.026658
# 					name: NCL2-factory , total: -71,469.8753684
# 					name: VAT3-sales , total: -40,535.153194
# 					name: LUX4-sales , total: -44,802.011425
# 				name: 2343 , total: -2,129,911.84045
# 					name: CUW1-distributor , total: -101,589.291035
# 					name: GBR1-sales , total: -109,670.257367
# 					name: DZA1-tax_entity , total: -108,515.833605
# 					name: ARM1-factory , total: -62,338.883135
# 					name: AGO3-sales , total: -15,007.5089029
# 					name: DJI2-factory , total: -53,103.4930409
# 					name: MYS3-hq , total: -66,956.5781821
# 					name: NPL2-tax_entity , total: -91,199.477179
# 					name: GUM2-factory , total: -18,470.7801882
# 					name: ATA1-tax_entity , total: -53,103.4930409
# 					name: COD1-hq , total: -35,787.1366145
# 					name: COG1-tax_entity , total: -13,853.0851411
# 					name: FLK1-distributor , total: -114,287.952414
# 					name: SXM3-factory , total: -36,941.5603763
# 					name: HKG2-factory , total: -41,559.2554233
# 					name: BFA3-distributor , total: -109,670.257367
# 					name: TON1-distributor , total: -100,434.867273
# 					name: AGO2-rd_center , total: -30,015.0178057
# 					name: ALA1-rd_center , total: -80,809.6633232
# 					name: CPV3-tax_entity , total: -94,662.7484643
# 					name: MAC1-distributor , total: -23,088.4752352
# 					name: GUF1-distributor , total: -24,242.898997
# 					name: POL1-tax_entity , total: -92,353.9009408
# 					name: SWE2-factory , total: -48,485.7979939
# 					name: LUX2-distributor , total: -48,485.7979939
# 					name: POL2-factory , total: -4,617.69504704
# 					name: DJI3-sales , total: -114,287.952414
# 					name: ARG1-sales , total: -25,397.3227587
# 					name: TJK2-rd_center , total: -38,095.9841381
# 					name: BES3-tax_entity , total: -19,625.2039499
# 					name: MWI2-sales , total: -81,964.0870849
# 					name: HMD1-rd_center , total: -24,242.898997
# 					name: NCL2-factory , total: -36,941.5603763
# 					name: LIE2-tax_entity , total: -6,926.54257056
# 					name: KHM2-rd_center , total: -77,346.3920379
# 					name: LUX4-sales , total: -73,883.1207526
# 					name: LKA1-distributor , total: -51,949.0692792
# 				name: 2383 , total: -2,282,048.40048
# 					name: GBR1-sales , total: -28,062.0795843
# 					name: GRD1-sales , total: -20,044.3425602
# 					name: DMA2-sales , total: -97,215.061417
# 					name: ARM1-factory , total: -97,215.061417
# 					name: AGO3-sales , total: -50,110.8564005
# 					name: ALA1-rd_center , total: -87,192.8901369
# 					name: MYS3-hq , total: -65,144.1133206
# 					name: NPL2-tax_entity , total: -99,219.495673
# 					name: ATF2-factory , total: -60,133.0276806
# 					name: GUM2-factory , total: -35,077.5994803
# 					name: ATA1-tax_entity , total: -26,057.6453283
# 					name: COD1-hq , total: -62,137.4619366
# ...
# 					name: GBR1-sales , total: -368,584,239.246
# 					name: AND2-rd_center , total: -47,699,136.8437
# 					name: DJI3-sales , total: -242,831,969.386
# 					name: ARG1-sales , total: -303,539,961.732
# 					name: BES3-tax_entity , total: -91,061,988.5197
# 					name: TJK2-rd_center , total: -420,619,661.258
# 					name: HMD1-rd_center , total: -151,769,980.866
# 					name: NCL2-factory , total: -160,442,551.201
# 					name: VAT3-sales , total: -364,247,954.079
# 					name: KHM2-rd_center , total: -364,247,954.079
# 				name: 2904 , total: -8,631,038,359.49
# 					name: CUW1-distributor , total: -163,042,046.933
# 					name: DZA1-tax_entity , total: -346,464,349.732
# 					name: GRD1-sales , total: -76,425,959.4997
# 					name: ARM1-factory , total: -81,521,023.4663
# 					name: AGO3-sales , total: -473,840,948.898
# 					name: ALA1-rd_center , total: -122,281,535.199
# 					name: MYS3-hq , total: -366,844,605.598
# 					name: NPL2-tax_entity , total: -285,323,582.132
# 					name: MAC2-factory , total: -254,753,198.332
# 					name: ATF2-factory , total: -438,175,501.131
# 					name: TLS3-distributor , total: -463,650,820.965
# 					name: GUM2-factory , total: -382,129,797.498
# 					name: ATA1-tax_entity , total: -25,475,319.8332
# 					name: COD1-hq , total: -377,034,733.532
# 					name: GUF1-distributor , total: -45,855,575.6998
# 					name: HKG2-factory , total: -203,802,558.666
# 					name: TON1-distributor , total: -422,890,309.231
# 					name: AGO2-rd_center , total: -392,319,925.432
# 					name: DJI2-factory , total: -15,285,191.8999
# 					name: CPV3-tax_entity , total: -157,946,982.966
# 					name: MAC1-distributor , total: -320,989,029.899
# 					name: COG1-tax_entity , total: -25,475,319.8332
# 					name: IND2-rd_center , total: -193,612,430.732
# 					name: IND3-hq , total: -219,087,750.566
# 					name: LUX2-distributor , total: -71,330,895.533
# 					name: POL2-factory , total: -433,080,437.165
# 					name: AND2-rd_center , total: -499,316,268.731
# 					name: DJI3-sales , total: -35,665,447.7665
# 					name: ARG1-sales , total: -392,319,925.432
# 					name: TJK2-rd_center , total: -361,749,541.632
# 					name: FLK1-distributor , total: -183,422,302.799
# 					name: MWI2-sales , total: -203,802,558.666
# 					name: ISL1-factory , total: -81,521,023.4663
# 					name: HMD1-rd_center , total: -30,570,383.7999
# 					name: NCL2-factory , total: -127,376,599.166
# 					name: KHM2-rd_center , total: -15,285,191.8999
# 					name: LUX4-sales , total: -341,369,285.765
# 			name: paid_capital , total: -6,862,516,357.49
# 				name: 2954 , total: -3,194,619,683.66
# 					name: CUW1-distributor , total: -59,451,050.4895
# 					name: DZA1-tax_entity , total: -106,662,178.819
# 					name: GRD1-sales , total: -136,387,704.064
# 					name: DMA2-sales , total: -68,193,852.0321
# 					name: ARM1-factory , total: -101,416,497.894
# 					name: AGO3-sales , total: -120,650,661.288
# 					name: MYS3-hq , total: -124,147,781.905
# 					name: NPL2-tax_entity , total: -82,182,334.5002
# 					name: MAC2-factory , total: -62,948,171.1065
# 					name: TLS3-distributor , total: -40,216,887.0959
# 					name: GUM2-factory , total: -159,118,988.075
# 					name: HND2-tax_entity , total: -169,610,349.926
# 					name: COD1-hq , total: -57,702,490.181
# 					name: NER1-rd_center , total: -15,737,042.7766
# 					name: SXM3-factory , total: -89,176,575.7343
# 					name: HKG2-factory , total: -19,234,163.3937
# 					name: BFA3-distributor , total: -111,907,859.745
# 					name: ISL1-factory , total: -118,902,100.979
# 					name: AGO2-rd_center , total: -17,485,603.0852
# 					name: JAM2-sales , total: -118,902,100.979
# 					name: MAC1-distributor , total: -54,205,369.564
# 					name: GUF1-distributor , total: -148,627,626.224
# 					name: IND2-rd_center , total: -20,982,723.7022
# 					name: IND3-hq , total: -83,930,894.8087
# 					name: POL1-tax_entity , total: -117,153,540.671
# 					name: LUX2-distributor , total: -12,239,922.1596
# 					name: AND2-rd_center , total: -152,124,746.841
# 					name: DJI3-sales , total: -61,199,610.798
# 					name: ARG1-sales , total: -10,491,361.8511
# 					name: FLK1-distributor , total: -159,118,988.075
# 					name: BES3-tax_entity , total: -174,856,030.852
# 					name: MWI2-sales , total: -83,930,894.8087
# 					name: TJK2-rd_center , total: -52,456,809.2555
# 					name: HMD1-rd_center , total: -117,153,540.671
# 					name: NCL2-factory , total: -50,708,248.9469
# 					name: VAT3-sales , total: -55,953,929.8725
# 					name: LIE2-tax_entity , total: -59,451,050.4895
# 				name: 2970 , total: -3,667,896,673.83
# 					name: DZA1-tax_entity , total: -75,067,811.403
# 					name: GRD1-sales , total: -25,022,603.801
# 					name: NER1-rd_center , total: -150,135,622.806
# 					name: ARM1-factory , total: -116,772,151.071
# 					name: MYS3-hq , total: -8,340,867.93366
# 					name: LKA1-distributor , total: -156,391,273.756
# 					name: MAC2-factory , total: -91,749,547.2703
# 					name: TLS3-distributor , total: -120,942,585.038
# 					name: GUM2-factory , total: -135,539,103.922
# 					name: ATA1-tax_entity , total: -50,045,207.602
# 					name: GUF1-distributor , total: -181,413,877.557
# 					name: SXM3-factory , total: -27,107,820.7844
# 					name: HKG2-factory , total: -79,238,245.3698
# 					name: TON1-distributor , total: -66,726,943.4693
# 					name: CUW1-distributor , total: -22,937,386.8176
# 					name: DJI2-factory , total: -18,766,952.8507
# 					name: JAM2-sales , total: -135,539,103.922
# 					name: MAC1-distributor , total: -6,255,650.95025
# 					name: COG1-tax_entity , total: -173,073,009.624
# 					name: IND2-rd_center , total: -162,646,924.706
# 					name: IND3-hq , total: -58,386,075.5356
# 					name: POL1-tax_entity , total: -10,426,084.9171
# 					name: SWE2-factory , total: -72,982,594.4196
# 					name: LUX2-distributor , total: -143,879,971.856
# 					name: AND2-rd_center , total: -145,965,188.839
# 					name: DJI3-sales , total: -164,732,141.69
# 					name: ARG1-sales , total: -152,220,839.789
# 					name: FLK1-distributor , total: -70,897,377.4361
# 					name: BES3-tax_entity , total: -177,243,443.59
# 					name: MWI2-sales , total: -108,431,283.138
# 					name: ISL1-factory , total: -170,987,792.64
# 					name: AGO2-rd_center , total: -166,817,358.673
# 					name: NCL2-factory , total: -87,579,113.3035
# 					name: VAT3-sales , total: -116,772,151.071
# 					name: LIE2-tax_entity , total: -33,363,471.7347
# 					name: KHM2-rd_center , total: -139,709,537.889
# 					name: LUX4-sales , total: -43,789,556.6517
# 			name: retained_earnings , total: -16,470,039,258.0
# 				name: 2972 , total: -2,589,176,477.23
# 					name: CUW1-distributor , total: -97,195,363.0662
# 					name: DZA1-tax_entity , total: -8,099,613.58885
# 					name: GRD1-sales , total: -125,544,010.627
# 					name: NER1-rd_center , total: -58,047,230.7201
# 					name: ARM1-factory , total: -89,095,749.4773
# 					name: AGO3-sales , total: -103,945,041.057
# 					name: MYS3-hq , total: -14,849,291.5796
# 					name: LKA1-distributor , total: -6,749,677.99071
# 					name: DMA2-sales , total: -89,095,749.4773
# 					name: HND2-tax_entity , total: -49,947,617.1312
# 					name: COD1-hq , total: -4,049,806.79442
# 					name: GUF1-distributor , total: -12,149,420.3833
# 					name: FLK1-distributor , total: -49,947,617.1312
# 					name: SXM3-factory , total: -122,844,139.431
# 					name: HKG2-factory , total: -107,994,847.851
# 					name: BFA3-distributor , total: -14,849,291.5796
# 					name: ISL1-factory , total: -56,697,295.1219
# 					name: AGO2-rd_center , total: -63,446,973.1126
# 					name: DJI2-factory , total: -48,597,681.5331
# 					name: CPV3-tax_entity , total: -128,243,881.823
# 					name: MAC1-distributor , total: -106,644,912.253
# 					name: COG1-tax_entity , total: -114,744,525.842
# 					name: IND2-rd_center , total: -97,195,363.0662
# 					name: IND3-hq , total: -132,293,688.618
# 					name: POL2-factory , total: -49,947,617.1312
# 					name: AND2-rd_center , total: -74,246,457.8978
# 					name: DJI3-sales , total: -31,048,518.7572
# 					name: TJK2-rd_center , total: -36,448,261.1498
# 					name: BES3-tax_entity , total: -110,694,719.048
# 					name: MWI2-sales , total: -80,996,135.8885
# 					name: TON1-distributor , total: -32,398,454.3554
# 					name: HMD1-rd_center , total: -113,394,590.244
# 					name: VAT3-sales , total: -28,348,647.561
# 					name: LIE2-tax_entity , total: -79,646,200.2903
# 					name: KHM2-rd_center , total: -101,245,169.861
# 					name: LUX4-sales , total: -48,597,681.5331
# 					name: NPL2-tax_entity , total: -99,895,234.2625
# 				name: 2982 , total: -4,890,666,679.22
# 					name: AGO2-rd_center , total: -49,113,460.3093
# 					name: GRD1-sales , total: -64,622,974.0912
# 					name: NER1-rd_center , total: -211,963,355.019
# 					name: ARM1-factory , total: -82,717,406.8367
# 					name: POL2-factory , total: -62,038,055.1275
# 					name: MYS3-hq , total: -178,359,408.492
# 					name: NPL2-tax_entity , total: -147,340,380.928
# 					name: ATF2-factory , total: -118,906,272.328
# 					name: DMA2-sales , total: -54,283,298.2366
# 					name: TLS3-distributor , total: -137,000,705.073
# 					name: DZA1-tax_entity , total: -118,906,272.328
# 					name: GUM2-factory , total: -10,339,675.8546
# 					name: ATA1-tax_entity , total: -95,642,001.655
# 					name: COD1-hq , total: -93,057,082.6913
# 					name: SXM3-factory , total: -87,887,244.764
# 					name: HKG2-factory , total: -2,584,918.96365
# 					name: ISL1-factory , total: -155,095,137.819
# 					name: CUW1-distributor , total: -38,773,784.4547
# 					name: DJI2-factory , total: -147,340,380.928
# 					name: MAC1-distributor , total: -165,434,813.673
# 					name: GUF1-distributor , total: -191,284,003.31
# 					name: IND2-rd_center , total: -155,095,137.819
# 					name: IND3-hq , total: -248,152,220.51
# 					name: POL1-tax_entity , total: -217,133,192.946
# 					name: SWE2-factory , total: -113,736,434.401
# 					name: LUX2-distributor , total: -211,963,355.019
# 					name: GBR1-sales , total: -7,754,756.89094
# 					name: AND2-rd_center , total: -222,303,030.874
# 					name: ARG1-sales , total: -134,415,786.11
# 					name: FLK1-distributor , total: -108,566,596.473
# 					name: TJK2-rd_center , total: -137,000,705.073
# 					name: MWI2-sales , total: -219,718,111.91
# 					name: HMD1-rd_center , total: -206,793,517.092
# 					name: NCL2-factory , total: -245,567,301.547
# 					name: VAT3-sales , total: -116,321,353.364
# 					name: LIE2-tax_entity , total: -131,830,867.146
# 					name: LKA1-distributor , total: -201,623,679.165
# 				name: 2989 , total: -1,726,117,651.49
# 					name: CUW1-distributor , total: -15,587,564.3433
# 					name: DMA2-sales , total: -35,277,119.3033
# 					name: GRD1-sales , total: -79,578,617.9632
# 					name: GBR1-sales , total: -58,248,266.7566
# 					name: ARM1-factory , total: -6,563,184.98665
# 					name: AGO3-sales , total: -44,301,498.6599
# 					name: LKA1-distributor , total: -50,044,285.5232
# 					name: MAC2-factory , total: -68,913,442.3599
# 					name: ATF2-factory , total: -45,942,294.9066
# 					name: TLS3-distributor , total: -72,195,034.8532
# 					name: DZA1-tax_entity , total: -57,427,868.6332
# 					name: ATA1-tax_entity , total: -46,762,693.0299
# 					name: HND2-tax_entity , total: -19,689,554.96
# 					name: COD1-hq , total: -22,150,749.33
# 					name: NER1-rd_center , total: -30,354,730.5633
# 					name: SXM3-factory , total: -51,685,081.7699
# 					name: BFA3-distributor , total: -26,252,739.9466
# 					name: TON1-distributor , total: -53,325,878.0166
# 					name: AGO2-rd_center , total: -48,403,489.2766
# 					name: DJI2-factory , total: -7,383,583.10999
# 					name: JAM2-sales , total: -79,578,617.9632
# 					name: MAC1-distributor , total: -45,942,294.9066
# 					name: GUF1-distributor , total: -56,607,470.5099
# 					name: IND2-rd_center , total: -76,297,025.4699
# 					name: IND3-hq , total: -75,476,627.3465
# 					name: POL1-tax_entity , total: -68,913,442.3599
# 					name: SWE2-factory , total: -79,578,617.9632
# 					name: LUX2-distributor , total: -72,195,034.8532
# 					name: AND2-rd_center , total: -63,991,053.6199
# 					name: DJI3-sales , total: -10,665,175.6033
# 					name: TJK2-rd_center , total: -78,758,219.8398
# 					name: ISL1-factory , total: -7,383,583.10999
# 					name: NCL2-factory , total: -22,971,147.4533
# 					name: VAT3-sales , total: -47,583,091.1532
# 					name: LIE2-tax_entity , total: -60,709,461.1265
# 					name: KHM2-rd_center , total: -30,354,730.5633
# 					name: LUX4-sales , total: -9,024,379.35665
# 				name: 2980 , total: -2,948,784,321.3
# 					name: DMA2-sales , total: -152,321,309.312
# 					name: GRD1-sales , total: -33,198,234.0808
# 					name: ARM1-factory , total: -7,811,349.19548
# 					name: AGO3-sales , total: -17,575,535.6898
# 					name: MYS3-hq , total: -76,160,654.656
# 					name: NPL2-tax_entity , total: -185,519,543.393
# 					name: MAC2-factory , total: -66,396,468.1616
# 					name: ATF2-factory , total: -171,849,682.301
# 					name: TLS3-distributor , total: -29,292,559.4831
# 					name: GUM2-factory , total: -156,226,983.91
# 					name: COD1-hq , total: -1,952,837.29887
# 					name: GUF1-distributor , total: -164,038,333.105
# 					name: SXM3-factory , total: -23,434,047.5865
# 					name: HKG2-factory , total: -25,386,884.8853
# 					name: BFA3-distributor , total: -93,736,190.3458
# 					name: TON1-distributor , total: -15,622,698.391
# 					name: CUW1-distributor , total: -19,528,372.9887
# 					name: DJI2-factory , total: -50,773,769.7706
# 					name: CPV3-tax_entity , total: -21,481,210.2876
# 					name: MAC1-distributor , total: -171,849,682.301
# 					name: COG1-tax_entity , total: -35,151,071.3797
# 					name: IND2-rd_center , total: -13,669,861.0921
# 					name: IND3-hq , total: -1,952,837.29887
# 					name: POL1-tax_entity , total: -123,028,749.829
# 					name: POL2-factory , total: -56,632,281.6673
# 					name: AND2-rd_center , total: -74,207,817.3571
# 					name: ARG1-sales , total: -189,425,217.99
# 					name: FLK1-distributor , total: -130,840,099.024
# 					name: TJK2-rd_center , total: -183,566,706.094
# 					name: MWI2-sales , total: -31,245,396.7819
# 					name: HMD1-rd_center , total: -162,085,495.806
# 					name: NCL2-factory , total: -82,019,166.5526
# 					name: VAT3-sales , total: -85,924,841.1503
# 					name: LIE2-tax_entity , total: -121,075,912.53
# 					name: KHM2-rd_center , total: -44,915,257.874
# 					name: LUX4-sales , total: -33,198,234.0808
# 					name: LKA1-distributor , total: -95,689,027.6447
# 				name: 2986 , total: -4,315,294,128.72
# 					name: DMA2-sales , total: -15,156,577.4717
# 					name: DZA1-tax_entity , total: -192,705,056.426
# 					name: AGO3-sales , total: -60,626,309.8868
# 					name: DJI2-factory , total: -134,243,971.892
# 					name: LKA1-distributor , total: -23,817,478.8841
# 					name: MAC2-factory , total: -181,878,929.66
# 					name: TLS3-distributor , total: -199,200,732.485
# 					name: GUM2-factory , total: -4,330,450.7062
# 					name: ATA1-tax_entity , total: -168,887,577.542
# 					name: HND2-tax_entity , total: -32,478,380.2965
# 					name: COD1-hq , total: -97,435,140.8894
# 					name: COG1-tax_entity , total: -192,705,056.426
# 					name: SXM3-factory , total: -168,887,577.542
# 					name: HKG2-factory , total: -119,087,394.42
# 					name: BFA3-distributor , total: -173,218,028.248
# 					name: ISL1-factory , total: -101,765,591.596
# 					name: CUW1-distributor , total: -155,896,225.423
# 					name: ALA1-rd_center , total: -184,044,155.013
# 					name: JAM2-sales , total: -15,156,577.4717
# 					name: CPV3-tax_entity , total: -99,600,366.2425
# 					name: MAC1-distributor , total: -164,557,126.835
# 					name: GUF1-distributor , total: -60,626,309.8868
# 					name: IND2-rd_center , total: -177,548,478.954
# 					name: IND3-hq , total: -207,861,633.897
# 					name: POL2-factory , total: -32,478,380.2965
# 					name: AND2-rd_center , total: -95,269,915.5363
# 					name: ARG1-sales , total: -151,565,774.717
# 					name: BES3-tax_entity , total: -10,826,126.7655
# 					name: TJK2-rd_center , total: -86,609,014.1239
# 					name: HMD1-rd_center , total: -4,330,450.7062
# 					name: AGO2-rd_center , total: -110,426,493.008
# 					name: NCL2-factory , total: -47,634,957.7682
# 					name: VAT3-sales , total: -132,078,746.539
# 					name: LIE2-tax_entity , total: -181,878,929.66
# 					name: KHM2-rd_center , total: -147,235,324.011
# 					name: LUX4-sales , total: -168,887,577.542
# 					name: NPL2-tax_entity , total: -214,357,309.957

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 13. Turn existing nested structure to a flat format - then to DataFrame format

# %%
fakeco_list = [x.split('|') for x in fakecompany.flatten()]

# %%
fakeco_list
# Out:
# [['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'DMA2-sales',
#   '-168638.444791'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'GRD1-sales',
#   '-98372.4261282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'ARM1-factory',
#   '-94357.2250618'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'AGO3-sales',
#   '-180684.047991'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'MYS3-hq',
#   '-194737.251723'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'NPL2-tax_entity',
#   '-114433.230394'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'MAC2-factory',
#   '-60228.0159969'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'TLS3-distributor',
#   '-18068.4047991'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'GUM2-factory',
#   '-108410.428794'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'ATA1-tax_entity',
#   '-18068.4047991'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'HND2-tax_entity',
#   '-66250.8175966'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'COD1-hq',
#   '-170646.045324'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'FLK1-distributor',
#   '-74281.2197295'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'SXM3-factory',
#   '-62235.6165301'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'HKG2-factory',
#   '-98372.4261282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'BFA3-distributor',
#   '-62235.6165301'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'ISL1-factory',
#   '-58220.4154636'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'CUW1-distributor',
#   '-112425.629861'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'DJI2-factory',
#   '-22083.6058655'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'CPV3-tax_entity',
#   '-24091.2063987'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'IND2-rd_center',
#   '-44167.211731'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'POL1-tax_entity',
#   '-106402.828261'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'SWE2-factory',
#   '-198752.45279'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'LUX2-distributor',
#   '-42159.6111978'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'DJI3-sales',
#   '-122463.632527'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'ARG1-sales',
#   '-126478.833593'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'TJK2-rd_center',
#   '-180684.047991'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'BES3-tax_entity',
#   '-166630.844258'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'MWI2-sales',
#   '-80304.0213292'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'HMD1-rd_center',
#   '-126478.833593'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'AGO2-rd_center',
#   '-134509.235726'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'NCL2-factory',
#   '-118448.431461'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'VAT3-sales',
#   '-138524.436793'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'LIE2-tax_entity',
#   '-108410.428794'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'KHM2-rd_center',
#   '-146554.838926'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'LUX4-sales',
#   '-168638.444791'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2025',
#   'LKA1-distributor',
#   '-180684.047991'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'AGO2-rd_center',
#   '-116966.241899'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'GRD1-sales',
#   '-336277.945459'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'NER1-rd_center',
#   '-180322.95626'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'ARM1-factory',
#   '-219311.70356'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'AGO3-sales',
#   '-238806.07721'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'MYS3-hq',
#   '-238806.07721'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'NPL2-tax_entity',
#   '-472738.561007'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'ATF2-factory',
#   '-263174.044272'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'TLS3-distributor',
#   '-243679.670622'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'DZA1-tax_entity',
#   '-263174.044272'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'ATA1-tax_entity',
#   '-219311.70356'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'HND2-tax_entity',
#   '-448370.593945'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'COD1-hq',
#   '-341151.538871'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'SXM3-factory',
#   '-121839.835311'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'HKG2-factory',
#   '-204690.923323'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'ISL1-factory',
#   '-151081.395786'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'CUW1-distributor',
#   '-321657.165221'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'DJI2-factory',
#   '-307036.384984'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'JAM2-sales',
#   '-160828.582611'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'CPV3-tax_entity',
#   '-190070.143085'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'MAC1-distributor',
#   '-268047.637684'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'COG1-tax_entity',
#   '-14620.7802373'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'IND2-rd_center',
#   '-458117.78077'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'IND3-hq',
#   '-448370.593945'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'POL1-tax_entity',
#   '-404508.253233'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'SWE2-factory',
#   '-24367.9670622'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'LUX2-distributor',
#   '-419129.03347'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'POL2-factory',
#   '-53609.5275369'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'ARG1-sales',
#   '-58483.1209493'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'TJK2-rd_center',
#   '-53609.5275369'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'FLK1-distributor',
#   '-4873.59341245'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'MWI2-sales',
#   '-43862.340712'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'NCL2-factory',
#   '-165702.176023'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'VAT3-sales',
#   '-136460.615548'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'LIE2-tax_entity',
#   '-165702.176023'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'LUX4-sales',
#   '-419129.03347'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2017',
#   'LKA1-distributor',
#   '-82851.0880116'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'DZA1-tax_entity',
#   '-217591.351377'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'GRD1-sales',
#   '-60025.2003799'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'DMA2-sales',
#   '-292622.851852'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'ARM1-factory',
#   '-600252.003799'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'AGO3-sales',
#   '-525220.503324'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'MYS3-hq',
#   '-570239.403609'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'NPL2-tax_entity',
#   '-82534.6505223'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'MAC2-factory',
#   '-15006.300095'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'ATF2-factory',
#   '-525220.503324'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'TLS3-distributor',
#   '-532723.653371'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'GUM2-factory',
#   '-255107.101614'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'ATA1-tax_entity',
#   '-45018.9002849'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'HND2-tax_entity',
#   '-727805.554606'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'COG1-tax_entity',
#   '-592748.853751'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'SXM3-factory',
#   '-157566.150997'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'HKG2-factory',
#   '-712799.254511'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'BFA3-distributor',
#   '-360151.202279'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'TON1-distributor',
#   '-607755.153846'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'CUW1-distributor',
#   '-495207.903134'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'DJI2-factory',
#   '-510214.203229'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'MAC1-distributor',
#   '-600252.003799'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'GUF1-distributor',
#   '-202585.051282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'IND2-rd_center',
#   '-172572.451092'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'IND3-hq',
#   '-225094.501424'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'POL1-tax_entity',
#   '-457692.152896'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'LUX2-distributor',
#   '-37515.7502374'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'GBR1-sales',
#   '-45018.9002849'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'AND2-rd_center',
#   '-135056.700855'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'DJI3-sales',
#   '-637767.754036'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'ARG1-sales',
#   '-720302.404558'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'BES3-tax_entity',
#   '-195081.901235'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'MWI2-sales',
#   '-525220.503324'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'ISL1-factory',
#   '-382660.652422'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'AGO2-rd_center',
#   '-337641.752137'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'VAT3-sales',
#   '-277616.551757'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'KHM2-rd_center',
#   '-142559.850902'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2011',
#   'LUX4-sales',
#   '-210088.20133'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'CUW1-distributor',
#   '-29668.7660857'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'DMA2-sales',
#   '-28908.0284938'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'GRD1-sales',
#   '-28147.2909018'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'NER1-rd_center',
#   '-27386.5533099'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'ARM1-factory',
#   '-26625.815718'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'MYS3-hq',
#   '-8748.48230733'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'NPL2-tax_entity',
#   '-37656.5108011'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'MAC2-factory',
#   '-33092.0852495'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'TLS3-distributor',
#   '-25104.3405341'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'DZA1-tax_entity',
#   '-33092.0852495'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'GUM2-factory',
#   '-34993.9292293'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'ATA1-tax_entity',
#   '-13312.907859'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'GUF1-distributor',
#   '-21300.6525744'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'SXM3-factory',
#   '-30049.1348817'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'HKG2-factory',
#   '-33092.0852495'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'BFA3-distributor',
#   '-37656.5108011'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'TON1-distributor',
#   '-23582.8653502'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'AGO2-rd_center',
#   '-34613.5604333'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'DJI2-factory',
#   '-38036.8795971'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'JAM2-sales',
#   '-28908.0284938'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'CPV3-tax_entity',
#   '-15595.1206348'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'COG1-tax_entity',
#   '-32331.3476575'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'IND2-rd_center',
#   '-14454.0142469'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'IND3-hq',
#   '-34993.9292293'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'POL1-tax_entity',
#   '-32331.3476575'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'SWE2-factory',
#   '-6466.2695315'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'LUX2-distributor',
#   '-15214.7518388'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'POL2-factory',
#   '-22061.3901663'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'AND2-rd_center',
#   '-5325.16314359'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'DJI3-sales',
#   '-29668.7660857'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'TJK2-rd_center',
#   '-26625.815718'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'FLK1-distributor',
#   '-25484.70933'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'ISL1-factory',
#   '-17116.5958187'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'VAT3-sales',
#   '-18638.0710026'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'KHM2-rd_center',
#   '-23963.2341462'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'LUX4-sales',
#   '-28908.0284938'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2035',
#   'LKA1-distributor',
#   '-9509.21989927'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'DMA2-sales',
#   '-17432.9773406'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'GRD1-sales',
#   '-3735.63800155'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'DZA1-tax_entity',
#   '-12274.239148'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'ARM1-factory',
#   '-2490.42533437'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'AGO3-sales',
#   '-12985.7892435'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'ALA1-rd_center',
#   '-7115.50095533'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'LKA1-distributor',
#   '-17610.8648645'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'MAC2-factory',
#   '-16899.3147689'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'ATF2-factory',
#   '-4269.3005732'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'TLS3-distributor',
#   '-6403.9508598'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'GUM2-factory',
#   '-16187.7646734'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'ATA1-tax_entity',
#   '-7471.2760031'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'HND2-tax_entity',
#   '-17610.8648645'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'COD1-hq',
#   '-16187.7646734'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'NER1-rd_center',
#   '-5158.73819262'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'SXM3-factory',
#   '-17788.7523883'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'GBR1-sales',
#   '-12807.9017196'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'HKG2-factory',
#   '-17432.9773406'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'ISL1-factory',
#   '-10139.5888614'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'CUW1-distributor',
#   '-13163.6767674'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'DJI2-factory',
#   '-12985.7892435'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'CPV3-tax_entity',
#   '-9428.03876582'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'MAC1-distributor',
#   '-4447.18809708'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'GUF1-distributor',
#   '-2312.53781048'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'IND2-rd_center',
#   '-3735.63800155'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'IND3-hq',
#   '-15120.4395301'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'SWE2-factory',
#   '-6226.06333592'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'LUX2-distributor',
#   '-13697.339339'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'POL2-factory',
#   '-15654.1021017'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'DJI3-sales',
#   '-7649.16352698'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'ARG1-sales',
#   '-17077.2022928'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'FLK1-distributor',
#   '-17610.8648645'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'HMD1-rd_center',
#   '-15298.327054'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'NCL2-factory',
#   '-8182.82609863'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'KHM2-rd_center',
#   '-6403.9508598'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'LUX4-sales',
#   '-6403.9508598'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'trade_payables',
#   '2031',
#   'NPL2-tax_entity',
#   '-2312.53781048'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'CUW1-distributor',
#   '-9594.65353255'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'DMA2-sales',
#   '-14200.0872282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'GRD1-sales',
#   '-14391.9802988'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'DZA1-tax_entity',
#   '-1535.14456521'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'ARM1-factory',
#   '-3454.07527172'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'AGO3-sales',
#   '-16119.0179347'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'MYS3-hq',
#   '-12856.8357336'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'NER1-rd_center',
#   '-6140.57826083'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'LKA1-distributor',
#   '-12856.8357336'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'MAC2-factory',
#   '-6140.57826083'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'ATF2-factory',
#   '-18997.4139944'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'TLS3-distributor',
#   '-2302.71684781'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'GUF1-distributor',
#   '-15351.4456521'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'HKG2-factory',
#   '-13432.5149456'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'BFA3-distributor',
#   '-18229.8417118'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'TON1-distributor',
#   '-9594.65353255'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'AGO2-rd_center',
#   '-7291.93668474'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'ALA1-rd_center',
#   '-2494.60991846'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'MAC1-distributor',
#   '-575.679211953'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'COG1-tax_entity',
#   '-16119.0179347'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'IND2-rd_center',
#   '-5948.68519018'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'POL1-tax_entity',
#   '-13624.4080162'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'SWE2-factory',
#   '-17462.2694292'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'LUX2-distributor',
#   '-14967.6595108'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'POL2-factory',
#   '-12089.263451'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'AND2-rd_center',
#   '-14583.8733695'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'DJI3-sales',
#   '-3837.86141302'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'ARG1-sales',
#   '-17654.1624999'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'TJK2-rd_center',
#   '-12473.0495923'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'FLK1-distributor',
#   '-18037.9486412'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'MWI2-sales',
#   '-11129.7980978'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'ISL1-factory',
#   '-5948.68519018'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'HMD1-rd_center',
#   '-4989.21983692'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'NCL2-factory',
#   '-9402.7604619'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'VAT3-sales',
#   '-17654.1624999'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'LIE2-tax_entity',
#   '-7675.72282604'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2040',
#   'KHM2-rd_center',
#   '-10554.1188858'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'CUW1-distributor',
#   '-39078.112614'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'GBR1-sales',
#   '-128399.512875'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'NER1-rd_center',
#   '-93043.1252714'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'ARM1-factory',
#   '-143286.412918'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'MYS3-hq',
#   '-44660.7001303'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'NPL2-tax_entity',
#   '-139564.687907'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'ATF2-factory',
#   '-1860.86250543'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'DMA2-sales',
#   '-182364.525532'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'TLS3-distributor',
#   '-80017.0877334'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'DZA1-tax_entity',
#   '-104208.300304'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'GUM2-factory',
#   '-1860.86250543'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'ATA1-tax_entity',
#   '-173060.213005'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'HND2-tax_entity',
#   '-20469.4875597'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'COD1-hq',
#   '-167477.625488'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'COG1-tax_entity',
#   '-91182.262766'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'HKG2-factory',
#   '-160034.175467'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'BFA3-distributor',
#   '-91182.262766'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'TON1-distributor',
#   '-20469.4875597'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'AGO2-rd_center',
#   '-89321.4002605'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'JAM2-sales',
#   '-33495.5250977'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'CPV3-tax_entity',
#   '-180503.663026'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'MAC1-distributor',
#   '-9304.31252714'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'GUF1-distributor',
#   '-143286.412918'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'POL1-tax_entity',
#   '-24191.2125706'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'POL2-factory',
#   '-81877.9502388'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'AND2-rd_center',
#   '-80017.0877334'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'DJI3-sales',
#   '-135842.962896'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'ARG1-sales',
#   '-107930.025315'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'FLK1-distributor',
#   '-16747.7625488'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'TJK2-rd_center',
#   '-80017.0877334'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'MWI2-sales',
#   '-48382.4251411'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'HMD1-rd_center',
#   '-180503.663026'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'NCL2-factory',
#   '-91182.262766'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'LIE2-tax_entity',
#   '-148869.000434'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'KHM2-rd_center',
#   '-48382.4251411'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'LUX4-sales',
#   '-147008.137929'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2080',
#   'LKA1-distributor',
#   '-1860.86250543'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'GBR1-sales',
#   '-522251.109741'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'GRD1-sales',
#   '-390035.63892'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'NER1-rd_center',
#   '-555304.977446'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'ARM1-factory',
#   '-601580.392233'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'AGO3-sales',
#   '-264430.941641'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'LKA1-distributor',
#   '-323927.90351'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'MAC2-factory',
#   '-112383.150197'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'ATF2-factory',
#   '-323927.90351'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'TLS3-distributor',
#   '-343760.224133'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'DZA1-tax_entity',
#   '-52886.1883282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'GUM2-factory',
#   '-528861.883282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'ATA1-tax_entity',
#   '-396646.412461'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'COD1-hq',
#   '-59496.9618692'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'GUF1-distributor',
#   '-608191.165774'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'SXM3-factory',
#   '-52886.1883282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'HKG2-factory',
#   '-442921.827248'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'BFA3-distributor',
#   '-171880.112067'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'TON1-distributor',
#   '-204933.979772'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'MAC1-distributor',
#   '-502418.789118'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'COG1-tax_entity',
#   '-165269.338526'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'IND2-rd_center',
#   '-271041.715182'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'IND3-hq',
#   '-442921.827248'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'POL1-tax_entity',
#   '-594969.618692'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'SWE2-factory',
#   '-6610.77354102'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'LUX2-distributor',
#   '-224766.300395'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'POL2-factory',
#   '-608191.165774'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'AND2-rd_center',
#   '-482586.468495'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'DJI3-sales',
#   '-218155.526854'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'ARG1-sales',
#   '-535472.656823'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'BES3-tax_entity',
#   '-475975.694954'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'TJK2-rd_center',
#   '-251209.394559'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'HMD1-rd_center',
#   '-528861.883282'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'NCL2-factory',
#   '-628023.486397'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'VAT3-sales',
#   '-489197.242036'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'LIE2-tax_entity',
#   '-13221.547082'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'KHM2-rd_center',
#   '-363592.544756'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2049',
#   'LUX4-sales',
#   '-165269.338526'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'DZA1-tax_entity',
#   '-456704.73221'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'GRD1-sales',
#   '-54531.9083236'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'GBR1-sales',
#   '-265843.053078'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'ARM1-factory',
#   '-299925.49578'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'AGO3-sales',
#   '-102247.328107'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'ALA1-rd_center',
#   '-668015.876964'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'MYS3-hq',
#   '-368090.381184'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'NER1-rd_center',
#   '-224944.121835'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'LKA1-distributor',
#   '-279476.030159'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'MAC2-factory',
#   '-374906.869725'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'ATF2-factory',
#   '-54531.9083236'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'TLS3-distributor',
#   '-320374.961401'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'GUM2-factory',
#   '-224944.121835'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'HND2-tax_entity',
#   '-20449.4656214'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'GUF1-distributor',
#   '-558952.060317'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'FLK1-distributor',
#   '-449888.24367'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'SXM3-factory',
#   '-109063.816647'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'BFA3-distributor',
#   '-218127.633294'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'TON1-distributor',
#   '-606667.4801'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'DJI2-factory',
#   '-511236.640534'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'CPV3-tax_entity',
#   '-538502.594696'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'MAC1-distributor',
#   '-449888.24367'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'COG1-tax_entity',
#   '-429438.778048'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'SWE2-factory',
#   '-170412.213511'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'LUX2-distributor',
#   '-388539.846806'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'POL2-factory',
#   '-661199.388424'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'AND2-rd_center',
#   '-490787.174913'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'ARG1-sales',
#   '-381723.358265'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'BES3-tax_entity',
#   '-463521.220751'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'TJK2-rd_center',
#   '-402172.823887'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'MWI2-sales',
#   '-606667.4801'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'ISL1-factory',
#   '-429438.778048'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'HMD1-rd_center',
#   '-368090.381184'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'NCL2-factory',
#   '-177228.702052'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'LIE2-tax_entity',
#   '-395356.335346'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'KHM2-rd_center',
#   '-20449.4656214'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2090',
#   'LUX4-sales',
#   '-381723.358265'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'DZA1-tax_entity',
#   '-13878.932853'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'GBR1-sales',
#   '-312275.989192'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'AGO3-sales',
#   '-138789.32853'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'MYS3-hq',
#   '-256760.25778'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'MAC2-factory',
#   '-121440.662464'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'ATF2-factory',
#   '-208183.992795'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'DMA2-sales',
#   '-24288.1324927'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'TLS3-distributor',
#   '-138789.32853'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'GUM2-factory',
#   '-176956.393876'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'COD1-hq',
#   '-194305.059942'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'NER1-rd_center',
#   '-166547.194236'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'FLK1-distributor',
#   '-17348.6660662'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'SXM3-factory',
#   '-183895.860302'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'HKG2-factory',
#   '-163077.461023'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'BFA3-distributor',
#   '-90213.0635444'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'TON1-distributor',
#   '-235941.858501'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'ALA1-rd_center',
#   '-308806.255979'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'JAM2-sales',
#   '-145728.794956'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'GUF1-distributor',
#   '-225532.658861'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'IND2-rd_center',
#   '-97152.5299709'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'IND3-hq',
#   '-194305.059942'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'POL1-tax_entity',
#   '-6939.46642649'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'COG1-tax_entity',
#   '-281048.390273'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'LUX2-distributor',
#   '-72864.3974782'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'POL2-factory',
#   '-298397.056339'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'AND2-rd_center',
#   '-284518.123486'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'DJI3-sales',
#   '-156137.994596'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'ARG1-sales',
#   '-76334.1306914'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'BES3-tax_entity',
#   '-145728.794956'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'TJK2-rd_center',
#   '-117970.92925'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'MWI2-sales',
#   '-274108.923846'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'ISL1-factory',
#   '-281048.390273'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'HMD1-rd_center',
#   '-97152.5299709'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'NCL2-factory',
#   '-322685.188832'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'VAT3-sales',
#   '-45106.5317722'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'LIE2-tax_entity',
#   '-93682.7967576'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2093',
#   'LUX4-sales',
#   '-27757.865706'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'DMA2-sales',
#   '-292424.930265'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'DZA1-tax_entity',
#   '-204697.451185'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'ARM1-factory',
#   '-204697.451185'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'AGO3-sales',
#   '-263182.437238'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'MYS3-hq',
#   '-307046.176778'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'LKA1-distributor',
#   '-331414.920967'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'MAC2-factory',
#   '-180328.706997'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'ATF2-factory',
#   '-414268.651208'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'ATA1-tax_entity',
#   '-263182.437238'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'HND2-tax_entity',
#   '-394773.655857'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'COD1-hq',
#   '-238813.69305'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'SXM3-factory',
#   '-404521.153533'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'HKG2-factory',
#   '-414268.651208'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'TON1-distributor',
#   '-389899.90702'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'CUW1-distributor',
#   '-472753.637261'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'ALA1-rd_center',
#   '-302172.42794'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'JAM2-sales',
#   '-243687.441887'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'CPV3-tax_entity',
#   '-92601.2279172'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'MAC1-distributor',
#   '-248561.190725'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'COG1-tax_entity',
#   '-443511.144235'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'IND2-rd_center',
#   '-297298.679102'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'IND3-hq',
#   '-82853.7302417'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'POL1-tax_entity',
#   '-209571.200023'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'SWE2-factory',
#   '-43863.7395397'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'LUX2-distributor',
#   '-307046.176778'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'POL2-factory',
#   '-346036.16748'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'AND2-rd_center',
#   '-121843.720944'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'DJI3-sales',
#   '-458132.390748'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'BES3-tax_entity',
#   '-424016.148884'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'FLK1-distributor',
#   '-307046.176778'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'MWI2-sales',
#   '-443511.144235'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'ISL1-factory',
#   '-258308.6884'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'HMD1-rd_center',
#   '-34116.2418642'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'NCL2-factory',
#   '-43863.7395397'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'KHM2-rd_center',
#   '-107222.47443'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'LUX4-sales',
#   '-204697.451185'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'accrued_expenses',
#   '2071',
#   'NPL2-tax_entity',
#   '-63358.7348907'],
#  ['fakecompany',
# ...
#   'current',
#   'other_liab',
#   '2270',
#   'MAC2-factory',
#   '-28801.2930589'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'ATF2-factory',
#   '-37335.0095208'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'DMA2-sales',
#   '-6400.28734642'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'TLS3-distributor',
#   '-22401.0057125'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'DZA1-tax_entity',
#   '-26667.8639434'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'GUM2-factory',
#   '-50135.5842137'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'ATA1-tax_entity',
#   '-17067.4329238'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'COD1-hq',
#   '-43735.2968672'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'NER1-rd_center',
#   '-45868.7259827'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'HKG2-factory',
#   '-10667.1455774'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'ISL1-factory',
#   '-68269.7316952'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'CUW1-distributor',
#   '-59736.0152333'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'ALA1-rd_center',
#   '-13867.2892506'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'CPV3-tax_entity',
#   '-67203.0171375'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'MAC1-distributor',
#   '-19200.8620393'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'COG1-tax_entity',
#   '-83203.7355035'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'IND3-hq',
#   '-37335.0095208'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'GUF1-distributor',
#   '-57602.5861178'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'POL1-tax_entity',
#   '-100271.168427'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'LUX2-distributor',
#   '-4266.85823095'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'AND2-rd_center',
#   '-68269.7316952'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'DJI3-sales',
#   '-91737.4519654'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'BES3-tax_entity',
#   '-76803.4481571'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'FLK1-distributor',
#   '-73603.3044839'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'MWI2-sales',
#   '-102404.597543'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'TJK2-rd_center',
#   '-99204.4538696'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'HMD1-rd_center',
#   '-104538.026658'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'NCL2-factory',
#   '-71469.8753684'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'VAT3-sales',
#   '-40535.153194'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2270',
#   'LUX4-sales',
#   '-44802.011425'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'CUW1-distributor',
#   '-101589.291035'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'GBR1-sales',
#   '-109670.257367'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'DZA1-tax_entity',
#   '-108515.833605'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'ARM1-factory',
#   '-62338.883135'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'AGO3-sales',
#   '-15007.5089029'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'DJI2-factory',
#   '-53103.4930409'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'MYS3-hq',
#   '-66956.5781821'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'NPL2-tax_entity',
#   '-91199.477179'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'GUM2-factory',
#   '-18470.7801882'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'ATA1-tax_entity',
#   '-53103.4930409'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'COD1-hq',
#   '-35787.1366145'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'COG1-tax_entity',
#   '-13853.0851411'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'FLK1-distributor',
#   '-114287.952414'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'SXM3-factory',
#   '-36941.5603763'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'HKG2-factory',
#   '-41559.2554233'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'BFA3-distributor',
#   '-109670.257367'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'TON1-distributor',
#   '-100434.867273'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'AGO2-rd_center',
#   '-30015.0178057'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'ALA1-rd_center',
#   '-80809.6633232'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'CPV3-tax_entity',
#   '-94662.7484643'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'MAC1-distributor',
#   '-23088.4752352'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'GUF1-distributor',
#   '-24242.898997'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'POL1-tax_entity',
#   '-92353.9009408'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'SWE2-factory',
#   '-48485.7979939'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'LUX2-distributor',
#   '-48485.7979939'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'POL2-factory',
#   '-4617.69504704'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'DJI3-sales',
#   '-114287.952414'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'ARG1-sales',
#   '-25397.3227587'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'TJK2-rd_center',
#   '-38095.9841381'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'BES3-tax_entity',
#   '-19625.2039499'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'MWI2-sales',
#   '-81964.0870849'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'HMD1-rd_center',
#   '-24242.898997'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'NCL2-factory',
#   '-36941.5603763'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'LIE2-tax_entity',
#   '-6926.54257056'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'KHM2-rd_center',
#   '-77346.3920379'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'LUX4-sales',
#   '-73883.1207526'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2343',
#   'LKA1-distributor',
#   '-51949.0692792'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'GBR1-sales',
#   '-28062.0795843'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'GRD1-sales',
#   '-20044.3425602'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'DMA2-sales',
#   '-97215.061417'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'ARM1-factory',
#   '-97215.061417'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'AGO3-sales',
#   '-50110.8564005'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'ALA1-rd_center',
#   '-87192.8901369'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'MYS3-hq',
#   '-65144.1133206'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'NPL2-tax_entity',
#   '-99219.495673'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'ATF2-factory',
#   '-60133.0276806'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'GUM2-factory',
#   '-35077.5994803'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'ATA1-tax_entity',
#   '-26057.6453283'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'COD1-hq',
#   '-62137.4619366'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'CUW1-distributor',
#   '-57126.3762966'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'DJI2-factory',
#   '-99219.495673'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'JAM2-sales',
#   '-55121.9420405'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'CPV3-tax_entity',
#   '-85188.4558808'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'MAC1-distributor',
#   '-27059.8624563'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'GUF1-distributor',
#   '-65144.1133206'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'IND2-rd_center',
#   '-37082.0337364'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'IND3-hq',
#   '-24053.2110722'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'POL1-tax_entity',
#   '-41090.9022484'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'SWE2-factory',
#   '-43095.3365044'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'LUX2-distributor',
#   '-39086.4679924'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'POL2-factory',
#   '-43095.3365044'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'DJI3-sales',
#   '-62137.4619366'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'ARG1-sales',
#   '-89197.3243929'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'BES3-tax_entity',
#   '-94208.4100329'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'TJK2-rd_center',
#   '-66146.3304486'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'MWI2-sales',
#   '-85188.4558808'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'HMD1-rd_center',
#   '-100221.712801'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'AGO2-rd_center',
#   '-81179.5873688'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'NCL2-factory',
#   '-86190.6730088'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'VAT3-sales',
#   '-76168.5017287'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'LIE2-tax_entity',
#   '-71157.4160887'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'KHM2-rd_center',
#   '-75166.2846007'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'LUX4-sales',
#   '-1002.21712801'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2383',
#   'LKA1-distributor',
#   '-50110.8564005'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'CUW1-distributor',
#   '-403.545252074'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'DZA1-tax_entity',
#   '-2017.72626037'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'GRD1-sales',
#   '-6456.72403318'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'DMA2-sales',
#   '-18159.5363433'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'ARM1-factory',
#   '-22194.9888641'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'AGO3-sales',
#   '-9281.5407977'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'LKA1-distributor',
#   '-38336.798947'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'ATF2-factory',
#   '-2017.72626037'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'TLS3-distributor',
#   '-13316.9933184'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'GUM2-factory',
#   '-403.545252074'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'ATA1-tax_entity',
#   '-16545.355335'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'COD1-hq',
#   '-35511.9821825'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'COG1-tax_entity',
#   '-18966.6268475'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'SXM3-factory',
#   '-9685.08604978'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'BES3-tax_entity',
#   '-32687.165418'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'BFA3-distributor',
#   '-20177.2626037'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'TON1-distributor',
#   '-4842.54302489'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'AGO2-rd_center',
#   '-8070.90504148'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'DJI2-factory',
#   '-807.090504148'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'JAM2-sales',
#   '-26230.4413848'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'CPV3-tax_entity',
#   '-14931.1743267'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'MAC1-distributor',
#   '-34704.8916784'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'GUF1-distributor',
#   '-13316.9933184'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'POL1-tax_entity',
#   '-34301.3464263'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'SWE2-factory',
#   '-31880.0749138'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'LUX2-distributor',
#   '-29458.8034014'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'DJI3-sales',
#   '-4842.54302489'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'ARG1-sales',
#   '-17352.4458392'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'TJK2-rd_center',
#   '-22194.9888641'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'FLK1-distributor',
#   '-28651.7128973'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'ISL1-factory',
#   '-4035.45252074'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'HMD1-rd_center',
#   '-16141.810083'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'NCL2-factory',
#   '-4035.45252074'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'VAT3-sales',
#   '-6860.26928526'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'LIE2-tax_entity',
#   '-25019.8056286'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'KHM2-rd_center',
#   '-15334.7195788'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2224',
#   'LUX4-sales',
#   '-19370.1720996'],
#  ['fakecompany',
#   'liabilities',
#   'current',
#   'other_liab',
#   '2283',
#   'DMA2-sales',
#   '-75298.2468126'],
#  ...]

# %%
df = pd.DataFrame(fakeco_list)

# %%
df[6] = df[6].astype(float)

# %%
print df.info()
print df.shape
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10138 entries, 0 to 10137
# Data columns (total 7 columns):
# 0    10138 non-null object
# 1    10138 non-null object
# 2    10138 non-null object
# 3    10138 non-null object
# 4    10138 non-null object
# 5    10138 non-null object
# 6    10138 non-null float64
# dtypes: float64(1), object(6)
# memory usage: 554.5+ KB
# None
# (10138, 7)
#              0            1        2               3     4             5  \
# 0  fakecompany  liabilities  current  trade_payables  2025    DMA2-sales
# 1  fakecompany  liabilities  current  trade_payables  2025    GRD1-sales
# 2  fakecompany  liabilities  current  trade_payables  2025  ARM1-factory
# 3  fakecompany  liabilities  current  trade_payables  2025    AGO3-sales
# 4  fakecompany  liabilities  current  trade_payables  2025       MYS3-hq
#
#                6
# 0 -168638.444791
# 1  -98372.426128
# 2  -94357.225062
# 3 -180684.047991
# 4 -194737.251723

# %% [markdown]
# ### Note: Performance / Splitting:
#
#     Fakecompany --> FSLI --> subFSLI --> account --> legal Entity
#
# Up to this point, every split has ALL values. So account 2050 should be split over all Legal Entities. For the next section, there will be limited coverage. Some balances will be split to say A, B, C, and others to D, E, F. See below for a sample:
#
#     100 dollars in legal entity --> 60 group 1 ---> A 30
#                                                ---> B 20
#                                                ---> C 10
#                                 --> 40 group 2 ---> D 15
#                                                ---> E 15
#                                                ---> F 10
#
# As a result, splitting is more focused on smaller and smaller sets of data. This is supposed to represent a typical product hierarchy. Like Apple Hardware would have iMac, Macbook, iPhone. iPhone would not ALSO show in Apple Services.

# %% [markdown]
# ## Product Data Detail

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 14. Data Detail - randomly select what product detail will be available

# %%
maxfields = random.randint(2,4)
fieldPrefix = random.sample(fieldOptions,maxfields+1)
print fieldPrefix
# Out:
# ['SYSTEM', 'SEGMENT', 'PRODCODE', 'PROFITCTR']

# %%
fieldstack = fieldPrefix[:]

def cartesianRows(inlist):
    if len(inlist) == 1:
        seed = random.randint(2,5)
        return [inlist[0]+'_'+RandomWords().random_words()[0] for i in range(seed)]
    else:
        seed = random.randint(2,5)
        local_list = []
        for y in [inlist[0]+'_'+RandomWords().random_words()[0] for i in range(seed)]:
            local_list.extend( y +'-'+ z for z in cartesianRows(inlist[1:]))
        return local_list

# for fieldname in inlist:
#     seed = random.randint(2,6)
#     print [RandomWords().random_words() for i in range(seed)]

product_data = cartesianRows(fieldstack)

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ### 15. Do the final Split (may take a while)

# %%
product_data = [str(x) for x in product_data]

# %%
df.shape[0]
# Out:
# 10138

# %%
len(product_data)
df.shape

t_matrix = np.zeros([df.shape[0],len(product_data)])
for i in range(df.shape[0]):
    t_matrix[i,:] = splitSwingPct(len(product_data))
t_matrix
# Out:
# array([[-0.10625   , -0.0875    , -0.1125    , ...,  0.2875    ,
#          0.0125    ,  0.2       ],
#        [ 0.0387931 , -0.19396552, -0.03448276, ..., -0.04741379,
#         -0.06034483, -0.04741379],
#        [-0.07729469,  0.06280193, -0.07729469, ..., -0.16425121,
#         -0.06280193,  0.03864734],
#        ...,
#        [-0.14728682,  0.18604651,  0.01162791, ..., -0.03875969,
#         -0.0503876 ,  0.13565891],
#        [-0.12121212,  0.15824916,  0.05387205, ...,  0.10774411,
#         -0.15488215, -0.12794613],
#        [ 1.13636364,  1.86363636,  1.13636364, ...,  1.40909091,
#         -0.36363636, -0.09090909]])

# %%
(df[6].values * t_matrix.transpose()).transpose()
# Out:
# array([[  1.79178348e+04,   1.47558639e+04,   1.89718250e+04, ...,
#          -4.84835529e+04,  -2.10798056e+03,  -3.37276890e+04],
#        [ -3.81617170e+03,   1.90808585e+04,   3.39215263e+03, ...,
#           4.66420986e+03,   5.93626709e+03,   4.66420986e+03],
#        [  7.29331208e+03,  -5.92581607e+03,   7.29331208e+03, ...,
#           1.54982882e+04,   5.92581607e+03,  -3.64665604e+03],
#        ...,
#        [  2.16858229e+07,  -2.73926184e+07,  -1.71203865e+06, ...,
#           5.70679550e+06,   7.41883416e+06,  -1.99737843e+07],
#        [  2.04712215e+07,  -2.67263170e+07,  -9.09832068e+06, ...,
#          -1.81966414e+07,   2.61576719e+07,   2.16085116e+07],
#        [ -2.43587852e+08,  -3.99484078e+08,  -2.43587852e+08, ...,
#          -3.02048937e+08,   7.79481127e+07,   1.94870282e+07]])

# %%
df2 = pd.DataFrame((df[6].values * t_matrix.transpose()).transpose())
df2.columns = product_data
df2.head()
# Out:
#    SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROFITCTR_capital  \
# 0                                       17917.834759
# 1                                       -3816.171703
# 2                                        7293.312082
# 3                                       80097.052202
# 4                                           0.000000
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROFITCTR_furnaces  \
# 0                                       14755.863919
# 1                                       19080.858516
# 2                                       -5925.816067
# 3                                      -26078.110019
# 4                                       23861.086179
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROFITCTR_tire  \
# 0                                       18971.825039
# 1                                        3392.152625
# 2                                        7293.312082
# 3                                      -85685.218635
# 4                                        8466.837031
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROFITCTR_anticipation  \
# 0                                       37943.650078
# 1                                       -8056.362485
# 2                                       -7749.144087
# 3                                       39117.165029
# 4                                        6157.699659
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_components-PROFITCTR_star  \
# 0                                       28457.737558
# 1                                       13144.591422
# 2                                           0.000000
# 3                                      -14901.777154
# 4                                      -23091.373722
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_components-PROFITCTR_printout  \
# 0                                       36889.659798
# 1                                       11872.534188
# 2                                       -2279.160026
# 3                                      -26078.110019
# 4                                       33867.348126
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_pans-PROFITCTR_supply  \
# 0                                       40051.630638
# 1                                       -8904.400641
# 2                                      -19144.944215
# 3                                      -68920.719337
# 4                                      -16163.961605
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_pans-PROFITCTR_pipe  \
# 0                                       11593.893079
# 1                                      -19928.896673
# 2                                        7749.144087
# 3                                       72646.163625
# 4                                      -32327.923211
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_leapers-PROFITCTR_chart  \
# 0                                       10539.902799
# 1                                        4240.190781
# 2                                      -20056.608226
# 3                                       29803.554308
# 4                                      -19242.811435
#
#    SYSTEM_course-SEGMENT_wash-PRODCODE_leapers-PROFITCTR_chimney  \
# 0                                      -11593.893079
# 1                                      -13568.610500
# 2                                       12307.464138
# 3                                       -1862.722144
# 4                                       11545.686861
#
#                                ...                               \
# 0                              ...
# 1                              ...
# 2                              ...
# 3                              ...
# 4                              ...
#
#    SYSTEM_grain-SEGMENT_statement-PRODCODE_fruits-PROFITCTR_drips  \
# 0                                       24241.776439
# 1                                       12720.572344
# 2                                       14130.792159
# 3                                       70783.441481
# 4                                       36946.197955
#
#    SYSTEM_grain-SEGMENT_statement-PRODCODE_fruits-PROFITCTR_maximums  \
# 0                                      -38997.640358
# 1                                        3392.152625
# 2                                       11395.800128
# 3                                      -13039.055010
# 4                                       26170.223552
#
#    SYSTEM_grain-SEGMENT_statement-PRODCODE_contraband-PROFITCTR_circumference  \
# 0                                       48483.552877
# 1                                      -21200.953907
# 2                                        5469.984062
# 3                                      -89410.662923
# 4                                        5387.987202
#
#    SYSTEM_grain-SEGMENT_statement-PRODCODE_contraband-PROFITCTR_coordinate  \
# 0                                      -43213.601478
# 1                                      -12720.572344
# 2                                      -20056.608226
# 3                                      -76371.607914
# 4                                       28479.360924
#
#    SYSTEM_grain-SEGMENT_statement-PRODCODE_contraband-PROFITCTR_atom  \
# 0                                       38997.640358
# 1                                        5088.228938
# 2                                       10484.136118
# 3                                      -37254.442885
# 4                                      -38485.622870
#
#    SYSTEM_grain-SEGMENT_ore-PRODCODE_raise-PROFITCTR_churns  \
# 0                                      -52699.513997
# 1                                      -15264.686813
# 2                                       20056.608226
# 3                                       31666.276452
# 4                                       31558.210754
#
#    SYSTEM_grain-SEGMENT_ore-PRODCODE_raise-PROFITCTR_load  \
# 0                                       -9485.912519
# 1                                       12720.572344
# 2                                       -9116.640103
# 3                                      -68920.719337
# 4                                       10775.974404
#
#    SYSTEM_grain-SEGMENT_ore-PRODCODE_raise-PROFITCTR_bricks  \
# 0                                      -48483.552877
# 1                                        4664.209860
# 2                                       15498.288174
# 3                                       93136.107212
# 4                                      -18473.098978
#
#    SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-PROFITCTR_prop  \
# 0                                       -2107.980560
# 1                                        5936.267094
# 2                                        5925.816067
# 3                                       76371.607914
# 4                                      -37715.910413
#
#    SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-PROFITCTR_desks
# 0                                      -33727.688958
# 1                                        4664.209860
# 2                                       -3646.656041
# 3                                      -26078.110019
# 4                                      -31558.210754
#
# [5 rows x 83 columns]

# %%
df = pd.merge(df,df2, how='inner', left_index=True, right_index=True)

# %%
# def addProductData(x):
#     if int(x.name) % 1000 == 0:
#         print x.name,
#     select_products = random.sample(product_data, int(len(product_data)*.75))
#     bals = splitSwingBalance(x[6],len(select_products))
#     for j,k in zip(select_products,bals ):
#         x[j] = k
#     return x

# df = df.apply(addProductData,axis=1)

# %%
flat_df = pd.melt(df,id_vars=[0,1,2,3,4,5,6,], var_name='variable')

# %%
fieldlkup = {x:i for i,x in enumerate(fieldstack)}
for field in fieldstack:
     flat_df[field] = flat_df['variable'].map(lambda x : x.split('-')[fieldlkup[field]].split('_')[1])

# %%
flat_df
# Out:
#                   0            1        2                  3     4  \
# 0       fakecompany  liabilities  current     trade_payables  2025
# 1       fakecompany  liabilities  current     trade_payables  2025
# 2       fakecompany  liabilities  current     trade_payables  2025
# 3       fakecompany  liabilities  current     trade_payables  2025
# 4       fakecompany  liabilities  current     trade_payables  2025
# 5       fakecompany  liabilities  current     trade_payables  2025
# 6       fakecompany  liabilities  current     trade_payables  2025
# 7       fakecompany  liabilities  current     trade_payables  2025
# 8       fakecompany  liabilities  current     trade_payables  2025
# 9       fakecompany  liabilities  current     trade_payables  2025
# 10      fakecompany  liabilities  current     trade_payables  2025
# 11      fakecompany  liabilities  current     trade_payables  2025
# 12      fakecompany  liabilities  current     trade_payables  2025
# 13      fakecompany  liabilities  current     trade_payables  2025
# 14      fakecompany  liabilities  current     trade_payables  2025
# 15      fakecompany  liabilities  current     trade_payables  2025
# 16      fakecompany  liabilities  current     trade_payables  2025
# 17      fakecompany  liabilities  current     trade_payables  2025
# 18      fakecompany  liabilities  current     trade_payables  2025
# 19      fakecompany  liabilities  current     trade_payables  2025
# 20      fakecompany  liabilities  current     trade_payables  2025
# 21      fakecompany  liabilities  current     trade_payables  2025
# 22      fakecompany  liabilities  current     trade_payables  2025
# 23      fakecompany  liabilities  current     trade_payables  2025
# 24      fakecompany  liabilities  current     trade_payables  2025
# 25      fakecompany  liabilities  current     trade_payables  2025
# 26      fakecompany  liabilities  current     trade_payables  2025
# 27      fakecompany  liabilities  current     trade_payables  2025
# 28      fakecompany  liabilities  current     trade_payables  2025
# 29      fakecompany  liabilities  current     trade_payables  2025
# ...             ...          ...      ...                ...   ...
# 841424  fakecompany       equity   equity  retained_earnings  2986
# 841425  fakecompany       equity   equity  retained_earnings  2986
# 841426  fakecompany       equity   equity  retained_earnings  2986
# 841427  fakecompany       equity   equity  retained_earnings  2986
# 841428  fakecompany       equity   equity  retained_earnings  2986
# 841429  fakecompany       equity   equity  retained_earnings  2986
# 841430  fakecompany       equity   equity  retained_earnings  2986
# 841431  fakecompany       equity   equity  retained_earnings  2986
# 841432  fakecompany       equity   equity  retained_earnings  2986
# 841433  fakecompany       equity   equity  retained_earnings  2986
# 841434  fakecompany       equity   equity  retained_earnings  2986
# 841435  fakecompany       equity   equity  retained_earnings  2986
# 841436  fakecompany       equity   equity  retained_earnings  2986
# 841437  fakecompany       equity   equity  retained_earnings  2986
# 841438  fakecompany       equity   equity  retained_earnings  2986
# 841439  fakecompany       equity   equity  retained_earnings  2986
# 841440  fakecompany       equity   equity  retained_earnings  2986
# 841441  fakecompany       equity   equity  retained_earnings  2986
# 841442  fakecompany       equity   equity  retained_earnings  2986
# 841443  fakecompany       equity   equity  retained_earnings  2986
# 841444  fakecompany       equity   equity  retained_earnings  2986
# 841445  fakecompany       equity   equity  retained_earnings  2986
# 841446  fakecompany       equity   equity  retained_earnings  2986
# 841447  fakecompany       equity   equity  retained_earnings  2986
# 841448  fakecompany       equity   equity  retained_earnings  2986
# 841449  fakecompany       equity   equity  retained_earnings  2986
# 841450  fakecompany       equity   equity  retained_earnings  2986
# 841451  fakecompany       equity   equity  retained_earnings  2986
# 841452  fakecompany       equity   equity  retained_earnings  2986
# 841453  fakecompany       equity   equity  retained_earnings  2986
#
#                        5             6  \
# 0             DMA2-sales -1.686384e+05
# 1             GRD1-sales -9.837243e+04
# 2           ARM1-factory -9.435723e+04
# 3             AGO3-sales -1.806840e+05
# 4                MYS3-hq -1.947373e+05
# 5        NPL2-tax_entity -1.144332e+05
# 6           MAC2-factory -6.022802e+04
# 7       TLS3-distributor -1.806840e+04
# 8           GUM2-factory -1.084104e+05
# 9        ATA1-tax_entity -1.806840e+04
# 10       HND2-tax_entity -6.625082e+04
# 11               COD1-hq -1.706460e+05
# 12      FLK1-distributor -7.428122e+04
# 13          SXM3-factory -6.223562e+04
# 14          HKG2-factory -9.837243e+04
# 15      BFA3-distributor -6.223562e+04
# 16          ISL1-factory -5.822042e+04
# 17      CUW1-distributor -1.124256e+05
# 18          DJI2-factory -2.208361e+04
# 19       CPV3-tax_entity -2.409121e+04
# 20        IND2-rd_center -4.416721e+04
# 21       POL1-tax_entity -1.064028e+05
# 22          SWE2-factory -1.987525e+05
# 23      LUX2-distributor -4.215961e+04
# 24            DJI3-sales -1.224636e+05
# 25            ARG1-sales -1.264788e+05
# 26        TJK2-rd_center -1.806840e+05
# 27       BES3-tax_entity -1.666308e+05
# 28            MWI2-sales -8.030402e+04
# 29        HMD1-rd_center -1.264788e+05
# ...                  ...           ...
# 841424      GUM2-factory -4.330451e+06
# 841425   ATA1-tax_entity -1.688876e+08
# 841426   HND2-tax_entity -3.247838e+07
# 841427           COD1-hq -9.743514e+07
# 841428   COG1-tax_entity -1.927051e+08
# 841429      SXM3-factory -1.688876e+08
# 841430      HKG2-factory -1.190874e+08
# 841431  BFA3-distributor -1.732180e+08
# 841432      ISL1-factory -1.017656e+08
# 841433  CUW1-distributor -1.558962e+08
# 841434    ALA1-rd_center -1.840442e+08
# 841435        JAM2-sales -1.515658e+07
# 841436   CPV3-tax_entity -9.960037e+07
# 841437  MAC1-distributor -1.645571e+08
# 841438  GUF1-distributor -6.062631e+07
# 841439    IND2-rd_center -1.775485e+08
# 841440           IND3-hq -2.078616e+08
# 841441      POL2-factory -3.247838e+07
# 841442    AND2-rd_center -9.526992e+07
# 841443        ARG1-sales -1.515658e+08
# 841444   BES3-tax_entity -1.082613e+07
# 841445    TJK2-rd_center -8.660901e+07
# 841446    HMD1-rd_center -4.330451e+06
# 841447    AGO2-rd_center -1.104265e+08
# 841448      NCL2-factory -4.763496e+07
# 841449        VAT3-sales -1.320787e+08
# 841450   LIE2-tax_entity -1.818789e+08
# 841451    KHM2-rd_center -1.472353e+08
# 841452        LUX4-sales -1.688876e+08
# 841453   NPL2-tax_entity -2.143573e+08
#
#                                                  variable         value  \
# 0       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  1.791783e+04
# 1       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -3.816172e+03
# 2       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  7.293312e+03
# 3       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  8.009705e+04
# 4       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  0.000000e+00
# 5       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  1.123271e+04
# 6       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  3.725444e+03
# 7       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -8.699602e+03
# 8       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -1.211646e+05
# 9       SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -9.441148e+02
# 10      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -4.674632e+03
# 11      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  6.750833e+04
# 12      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  3.419946e+03
# 13      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  2.551660e+04
# 14      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -7.392148e+03
# 15      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  1.484080e+04
# 16      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  3.712040e+03
# 17      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -1.338400e+04
# 18      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -1.421032e+03
# 19      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  1.859983e+03
# 20      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -2.355585e+04
# 21      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -1.916259e+04
# 22      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -7.155088e+04
# 23      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -2.670109e+05
# 24      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  3.711019e+04
# 25      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -5.386662e+03
# 26      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  9.034202e+02
# 27      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -2.162385e+04
# 28      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF... -5.917138e+03
# 29      SYSTEM_course-SEGMENT_wash-PRODCODE_photo-PROF...  6.745538e+03
# ...                                                   ...           ...
# 841424  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -4.563955e+05
# 841425  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -1.385291e+07
# 841426  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -7.580232e+05
# 841427  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  1.885841e+07
# 841428  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  7.467321e+07
# 841429  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  1.801467e+08
# 841430  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -2.630151e+07
# 841431  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  1.458678e+08
# 841432  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -4.649189e+06
# 841433  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -6.235849e+08
# 841434  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -5.889413e+07
# 841435  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  1.268080e+06
# 841436  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -1.846041e+07
# 841437  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  3.862843e+05
# 841438  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  9.857937e+05
# 841439  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -3.653261e+07
# 841440  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -2.095379e+06
# 841441  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  5.090655e+04
# 841442  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -3.276800e+06
# 841443  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  9.021772e+06
# 841444  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -4.539989e+05
# 841445  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  8.563038e+06
# 841446  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -3.504411e+05
# 841447  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  5.784245e+06
# 841448  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -2.053231e+06
# 841449  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -3.212726e+07
# 841450  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -5.417670e+07
# 841451  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P... -1.997378e+07
# 841452  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  2.160851e+07
# 841453  SYSTEM_grain-SEGMENT_ore-PRODCODE_semicolons-P...  1.948703e+07
#
#         SYSTEM SEGMENT    PRODCODE PROFITCTR
# 0       course    wash       photo   capital
# 1       course    wash       photo   capital
# 2       course    wash       photo   capital
# 3       course    wash       photo   capital
# 4       course    wash       photo   capital
# 5       course    wash       photo   capital
# 6       course    wash       photo   capital
# 7       course    wash       photo   capital
# 8       course    wash       photo   capital
# 9       course    wash       photo   capital
# 10      course    wash       photo   capital
# 11      course    wash       photo   capital
# 12      course    wash       photo   capital
# 13      course    wash       photo   capital
# 14      course    wash       photo   capital
# 15      course    wash       photo   capital
# 16      course    wash       photo   capital
# 17      course    wash       photo   capital
# 18      course    wash       photo   capital
# 19      course    wash       photo   capital
# 20      course    wash       photo   capital
# 21      course    wash       photo   capital
# 22      course    wash       photo   capital
# 23      course    wash       photo   capital
# 24      course    wash       photo   capital
# 25      course    wash       photo   capital
# 26      course    wash       photo   capital
# 27      course    wash       photo   capital
# 28      course    wash       photo   capital
# 29      course    wash       photo   capital
# ...        ...     ...         ...       ...
# 841424   grain     ore  semicolons     desks
# 841425   grain     ore  semicolons     desks
# 841426   grain     ore  semicolons     desks
# 841427   grain     ore  semicolons     desks
# 841428   grain     ore  semicolons     desks
# 841429   grain     ore  semicolons     desks
# 841430   grain     ore  semicolons     desks
# 841431   grain     ore  semicolons     desks
# 841432   grain     ore  semicolons     desks
# 841433   grain     ore  semicolons     desks
# 841434   grain     ore  semicolons     desks
# 841435   grain     ore  semicolons     desks
# 841436   grain     ore  semicolons     desks
# 841437   grain     ore  semicolons     desks
# 841438   grain     ore  semicolons     desks
# 841439   grain     ore  semicolons     desks
# 841440   grain     ore  semicolons     desks
# 841441   grain     ore  semicolons     desks
# 841442   grain     ore  semicolons     desks
# 841443   grain     ore  semicolons     desks
# 841444   grain     ore  semicolons     desks
# 841445   grain     ore  semicolons     desks
# 841446   grain     ore  semicolons     desks
# 841447   grain     ore  semicolons     desks
# 841448   grain     ore  semicolons     desks
# 841449   grain     ore  semicolons     desks
# 841450   grain     ore  semicolons     desks
# 841451   grain     ore  semicolons     desks
# 841452   grain     ore  semicolons     desks
# 841453   grain     ore  semicolons     desks
#
# [841454 rows x 13 columns]

# %% [markdown]
# <a href='#home'>Back to the top</a>
# ## Format the dataframe - drop additional columns

# %%
flat_df.rename(columns = {
        0:'company_name'
        , 1:'fsli_l1'
        , 2:'fsli_l2'
        , 3:'fsli_l3'
        , 4:'acct'
        , 5:'legal_entity'
        , 6:'total_amt'
        , 'value':'amount'
    }, inplace=True)
flat_df.drop(['variable','total_amt'],axis = 1,inplace=True)
flat_df.head()
# Out:
#   company_name      fsli_l1  fsli_l2         fsli_l3  acct  legal_entity  \
# 0  fakecompany  liabilities  current  trade_payables  2025    DMA2-sales
# 1  fakecompany  liabilities  current  trade_payables  2025    GRD1-sales
# 2  fakecompany  liabilities  current  trade_payables  2025  ARM1-factory
# 3  fakecompany  liabilities  current  trade_payables  2025    AGO3-sales
# 4  fakecompany  liabilities  current  trade_payables  2025       MYS3-hq
#
#          amount  SYSTEM SEGMENT PRODCODE PROFITCTR
# 0  17917.834759  course    wash    photo   capital
# 1  -3816.171703  course    wash    photo   capital
# 2   7293.312082  course    wash    photo   capital
# 3  80097.052202  course    wash    photo   capital
# 4      0.000000  course    wash    photo   capital

# %% [markdown]
# <a id='class'></a>
# <a href='#home'>Back to the top</a>
# ## Grand Finale: Putting it all together as two Classes: RCU, FakeCompanyFinancials

# %%
# import libraries
import os
import pycountry
import random 
import string
import numpy as np
import pandas as pd
from random_words import RandomWords
from decimal import *
       
def splitPosPct(n,swing=100):
    rand_nums = np.array([random.randint(1,swing) for i in range(n)])
    return rand_nums*1.0 / sum(rand_nums)

def splitSwingPct(n,swing=100):
    rand_nums = np.array([random.randint(-int(swing/2),int(swing/2)) for i in range(n)])
    return rand_nums*1.0 / sum(rand_nums)

def intSplit(count,n, minm=0,swing=100):
    base = [minm for i in range(n)]
    subcount = count - sum(base)
    first = [int(x*int(subcount)) for x in splitPosPct(n,swing)][:-1]
    first.append(subcount-sum(first))

    return list(np.array(first)+np.array(base))


def listSplit(inputlist,n,minm=2,swing=100):
    inlist = inputlist[:]
    inlist.sort()
    divs = intSplit(len(inlist),n,minm,swing=100)
    outlist = []
    for x in divs:
        divlist = []
        for i in range(x):
            divlist.append(inlist.pop(0))
        outlist.append(divlist)
    return outlist


def splitBalance(total, n, swing=100):
    return splitPosPct(n,swing)*total

def splitSwingBalance(total, n, swing=100):
    return splitSwingPct(n,swing) * total


class RCU(object):
    def __init__(self, name, total):
        self.name = name
        self.total = total
        self.delimiter = '|'
        self.items = {}
        
    def __str__(self):
        return 'name: %s , total: %s' % (self.name, "{:,}".format(self.total))
    
    def getItems(self):
        return self.items.values()
    
    #using recursive print
    def printItems(self,n=0):
        g = self.getItems()
        print n*'\t',self
        n+=1
        for x in g:
            x.printItems(n)
    
    def splitItems(self, labels,swing=100):
        n = len(labels)
        self.items = { j: RCU(j,k) for j,k in zip(labels, splitBalance(self.total,n,swing=100))}
        
    def explictItems(self, in_dict):
        if sum(in_dict.values()) == self.total:
            self.items = { j: RCU(j,k) for j,k in in_dict.items()}
        else:
            print 'total balance doesnt match submitted breakout of items'
    def splitEnds(self,labels):
        if len(self.getItems()) == 0:
            self.splitItems(random.sample(labels,int(len(labels)*.75)))
        else:
            for x in self.getItems():
                x.splitEnds(labels)
                
    def flatten(self):
        if len(self.getItems()) == 0:
            return [self.name+self.delimiter+str(self.total)]
        else:
            return_list = []
            for x in self.getItems():
                for y in x.flatten():
                    return_list.append(self.name +self.delimiter+ y)
            return return_list

#================================================================================================
#================================================================================================
#================================================================================================
        
# class construction
class FakeCompanyFinancials(object):
    def __struct__(self):
        self.bs_def ={
            'assets':{
                'current':{
                    'cash':1
                    ,'trade_receivables':2
                    ,'investments':3
                    ,'inventories':4
                    ,'assets_for_sale':5
                }
                ,'non-current':{
                    'ppe':6
                    ,'intangible':7
                    ,'goodwill':8
                }
            }
            , 'liabilities':{
                'current':{
                    'trade_payables':9
                    ,'accrued_expenses':10
                    ,'current_tax':11
                    ,'current_loans':12
                    ,'other_liab':13
                    ,'liab_for_sale':14
                }
                ,'non-current':{
                    'loans':15
                    , 'def_tax':16
                    , 'Other_non_liab':17

                }

            }
            , 'equity':{
                'equity':{
                    'capital_stock':18
                    , 'paid_capital':19
                    ,'retained_earnings':20
                   }
            }
        }
        self.fieldOptions = ('COSTCTR','PROFITCTR','PRODCODE','SEGMENT','BUSAREA', \
                             'PROGRAM','PROJECT','REFE','BGROUP','SKU','SYSTEM')
 

    def _updatedDataFrame(self):
        list_format = [x.split('|') for x in self.rootRCU.flatten()]
        self.dataf = pd.DataFrame(list_format)    
    
        
    def __init__(self
                 , name = 'fakeCompany'
                 , maxfields = random.randint(2,5)
                , maxrows = random.randint(100,400)
                , maxentities = random.randint(4,30)
                 , maxaccounts = random.randint(40,120)
                ):
        self.__struct__()
        
        self.name = name
        self.maxfields = maxfields
        self.maxrows = maxrows
        self.maxaccounts = maxaccounts
        
        # start with a couple of billion dollars as the inital company balance
        total_company_assets = random.randint(1,50)*1e9

        # back into liabilities with random % distribution
        total_company_liabilities = -random.random()*total_company_assets
        total_company_equity = -(total_company_assets + total_company_liabilities)

        # print the current total balances
        print 'Assets \t\t', "{:,}".format(total_company_assets)
        print 'Liabilities \t', "{:,}".format(total_company_liabilities)
        print 'Equity \t\t', "{:,}".format(total_company_equity)

        self.company = {
            'assets' :total_company_assets
            , 'liabilities' : total_company_liabilities
            , 'equity': total_company_equity
        }
        
        self.rootRCU = RCU(self.name, 0)
        
        # assigns basic FSLI balances
        self.rootRCU.explictItems(self.company)
        self._updatedDataFrame()
    

    
    
    def generateBalanceSheet(self, verbose=0):
        if verbose==1:
            print 'Splitting by FSLI'
        self._splitBySubFSLI()
        
        if verbose==1:
            print 'Making Fake Accounts'        
        self._generateAccounts()
        
        if verbose==1:
            print 'Splitting by Accounts'        
        self._splitByAccount()
        
        if verbose==1:
            print 'Splitting by Legal Entity'
        self._addLegalEntity()
        
        if verbose==1:
            print 'Updating stored dataframe'        
        self._updatedDataFrame()
        
        if verbose==1:
            print 'generate Data Detail'        
        self._generateDataDetail(verbose)
        

        if verbose==1:
            print 'storingCSV data'        
        self._generateCSV()
        
        
       


       
                
    def _splitBySubFSLI(self):
        for x in self.rootRCU.getItems():
            x.splitItems(self.bs_def[x.name].keys())
            for y in x.getItems():
                y.splitItems(self.bs_def[x.name][y.name].keys(),swing=10000)     
    
    def _generateAccounts(self):
        self.asset_accounts = [str(x).zfill(4) for x in random.sample(xrange(1000,1999), self.maxaccounts)]
        self.liab_accounts = [str(x).zfill(4) for x in random.sample(xrange(2000,2899), self.maxaccounts)]
        self.equity_accounts = [str(x).zfill(4) for x in random.sample(xrange(2900,2999), 10)]

        self.asset_accounts.sort()
        self.liab_accounts.sort()
        self.equity_accounts.sort()
    
    def _splitByAccount(self):
        for x in self.rootRCU.items['assets'].getItems():
            acct_ct = listSplit(self.asset_accounts,len(x.getItems()),2)
            for y,accts in zip(x.getItems(),acct_ct):
                y.splitItems(accts)

       
        for x in self.rootRCU.items['liabilities'].getItems():
            acct_ct = listSplit(self.liab_accounts,len(x.getItems()),2)
            for y,accts in zip(x.getItems(),acct_ct):
                y.splitItems(accts)

        for x in self.rootRCU.items['equity'].getItems():
            acct_ct = listSplit(self.equity_accounts,len(x.getItems()),2)
            for y,accts in zip(x.getItems(),acct_ct):
                y.splitItems(accts)
                
                
    def _addLegalEntity(self):
        self.alpha3 = [x.alpha3 for x in list(pycountry.countries)]
        self.alpha3_entity = []

        #typical transfer pricing legal entities
        le_functions = ['factory', 'distributor', 'sales','rd_center','tax_entity','hq']
        for y in self.alpha3:
            self.alpha3_entity.extend([str(y)+str(z)+'-'+random.sample(le_functions,1)[0] for z in range(1,random.randint(1,5))])

        #total dictionary of possible entities    
    
        random_le = random.sample(self.alpha3_entity,random.randint(30,80))
        random_le.sort()
        self.rootRCU.splitEnds(random_le)

    
    def _generateDataDetail(self,verbose=0):
   
        self.fieldPrefix = random.sample(self.fieldOptions,self.maxfields+1)
        if verbose !=0:
            print 'fields to generate', self.fieldPrefix
        
        #formatting amounts as float
        self.dataf[6] = self.dataf[6].astype(float)
        
        # recursive generator
        # 
        def cartesianRows(inlist):
            if len(inlist) == 1:
                seed = random.randint(2,5)
                return [inlist[0]+'_'+RandomWords().random_words()[0] for i in range(seed)]
            else:
                seed = random.randint(2,5)
                local_list = []
                for y in [inlist[0]+'_'+RandomWords().random_words()[0] for i in range(seed)]:
                    local_list.extend( y +'-'+ z for z in cartesianRows(inlist[1:]))
                return local_list

        
        
        self.product_data = [str(x) for x in cartesianRows(self.fieldPrefix)]
        
        if verbose !=0:
            print 'creating partition matrix'
        #create percentage split matrix
        rowcount_df =self.dataf.shape[0]
        t_matrix = np.zeros([rowcount_df,len(self.product_data)])
        for i in range(rowcount_df):
            t_matrix[i,:] = splitSwingPct(len(self.product_data))

        # pull all the amounts
        current_amounts = self.dataf[6].values
        
        
        if verbose !=0:
            print 'allocating balances'
        # create 'allocated balance* matrix with linear algebra
        alloc_amounts = (current_amounts*t_matrix.T).T
        
        # create a dataframe of the allocated balances.
        # update the columns
        add_dataf = pd.DataFrame(alloc_amounts)
        add_dataf.columns = self.product_data
        

        # merge existing dataframe with product data added
        self.dataf = pd.merge(self.dataf, add_dataf, how = 'inner',left_index=True,right_index=True)        
        
        flat_df = pd.melt(self.dataf,id_vars=[0,1,2,3,4,5,6], var_name='variable')
        
        #splits variable column into all the various fields that were encoded with _
        fieldlkup = {x:i for i,x in enumerate(self.fieldPrefix)}
        for field in self.fieldPrefix:
             flat_df[field] = flat_df['variable'].map(lambda x : x.split('-')[fieldlkup[field]].split('_')[1])
        
        
        # formatting the column names and dropping duplicate columns
        flat_df.rename(columns = {
                0:'company_name'
                , 1:'fsli_l1'
                , 2:'fsli_l2'
                , 3:'fsli_l3'
                , 4:'acct'
                , 5:'legal_entity'
                , 6:'total_amt'
                , 'value':'amount'
            }, inplace=True)
        flat_df.drop(['variable','total_amt'],axis = 1,inplace=True)
        self.dataf = flat_df
        
    def _generateCSV(self):
        self.CSVHeader = self.dataf.columns
        self.CSVList = self.dataf.to_csv()

# %% [markdown]
# #### Test new class - make a new company

# %%
sammys_bakery = FakeCompanyFinancials()
# Out:
# Assets 		37,000,000,000.0
# Liabilities 	-32,644,178,495.6
# Equity 		-4,355,821,504.39

# %% [markdown]
# #### generate the full detail

# %%
sammys_bakery.generateBalanceSheet(verbose=1)
# Out:
# Splitting by FSLI
# Making Fake Accounts
# Splitting by Accounts
# Splitting by Legal Entity
# Updating stored dataframe
# generate Data Detail
# fields to generate ['BUSAREA', 'SKU', 'PROJECT', 'PROFITCTR', 'SEGMENT', 'PROGRAM']
# creating partition matrix

# %% [markdown]
# #### check the dataframe output

# %%
sammys_bakery.dataf.head()
# Out:
#   company_name      fsli_l1  fsli_l2         fsli_l3  acct      legal_entity  \
# 0  fakeCompany  liabilities  current  trade_payables  2050      CHL1-factory
# 1  fakeCompany  liabilities  current  trade_payables  2050    CYP2-rd_center
# 2  fakeCompany  liabilities  current  trade_payables  2050           IMN3-hq
# 3  fakeCompany  liabilities  current  trade_payables  2050  SPM3-distributor
# 4  fakeCompany  liabilities  current  trade_payables  2050      IDN2-factory
#
#          amount      SYSTEM    PROGRAM     SKU  BGROUP
# 0  6.533658e+05  coordinate  principle  radars  boiler
# 1  2.794677e+05  coordinate  principle  radars  boiler
# 2 -1.216944e+06  coordinate  principle  radars  boiler
# 3 -2.538863e+05  coordinate  principle  radars  boiler
# 4  8.438122e+05  coordinate  principle  radars  boiler

# %% [markdown]
# #### Generate a second company

# %%
mikes_fish = FakeCompanyFinancials('mikes_fish')
mikes_fish.generateBalanceSheet(verbose=1)
# Out:
# Assets 		33,000,000,000.0
# Liabilities 	-13,406,276,289.1
# Equity 		-19,593,723,710.9
# Splitting by FSLI
# Making Fake Accounts
# Splitting by Accounts
# Splitting by Legal Entity
# Updating stored dataframe
# generate Data Detail
# fields to generate ['BGROUP', 'SKU', 'COSTCTR', 'BUSAREA']
# creating partition matrix
# allocating balances
# storingCSV data

# %% [markdown]
# #### check the dataframe output

# %%
mikes_fish.dataf.head()

# %% [markdown]
# <a href='#home'>Back to the top</a>
